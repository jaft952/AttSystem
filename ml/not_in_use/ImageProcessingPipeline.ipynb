# %% [markdown]
# ## Folder Structure for Dataset
#
# ```
# data/
# ├── raw/                     # Original images (before split)
# │   └── [person_name]/
# ├── train_raw/               # Training split (raw images)
# │   └── [person_name]/
# ├── test_raw/                # Test split (raw images)
# │   └── [person_name]/
# ├── converted/               # Standardized JPG images (train only)
# │   └── [person_name]/
# ├── preprocessed/            # Grayscale + CLAHE processed (train only)
# │   └── [person_name]/
# ├── faces_detected/          # Extracted face ROIs 128x128 (train only)
# │   └── [person_name]/
# ├── final_processed/         # Post-processed face ROIs (train only)
# │   └── [person_name]/
# ├── test_processed/          # Post-processed face ROIs from test_raw (test only)
# │   └── [person_name]/
# ├── augmented/               # Augmented face crops (train only)
# │   └── [person_name]/
# └── preview/                 # Preview & evaluation results
#     ├── augmentation_samples/
#     └── evaluation_results/
# models/
# ├── lbph_model.yml           # Trained LBPH face recognizer
# └── label_map.txt            # Person name → label ID mapping
# ```

# %%
# Import all required libraries
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import face_recognition
import time
import random
from pathlib import Path
from PIL import Image, ImageEnhance, ImageOps
import shutil
import tempfile
import dlib

# For HEIC conversion
try:
    from pillow_heif import register_heif_opener
    register_heif_opener()
    HAS_HEIF_SUPPORT = True
    print("✅ HEIC support available")
except ImportError:
    HAS_HEIF_SUPPORT = False
    print("⚠️  HEIC support not available. Install pillow-heif if needed.")

# For advanced augmentation
try:
    import albumentations as A
    HAS_ALBUMENTATIONS = True
    print("✅ Advanced augmentation available")
except ImportError:
    HAS_ALBUMENTATIONS = False
    print("⚠️  Advanced augmentation not available. Install albumentations if needed.")

try:
    import dlib
    print("✅ dlib support available")
except ImportError:
    print("⚠️  dlib support not available. Install dlib if needed.")

print("📦 Core libraries loaded successfully!")
# Out:
# ✅ HEIC support available
# ✅ Advanced augmentation available
# ✅ dlib support available
# 📦 Core libraries loaded successfully!

# %% [markdown]
# # Configuration Settings

# %%
# === CONFIGURATION SETTINGS ===

# File paths
DATA_FOLDER = os.path.join("..", "data")
RAW_FOLDER = os.path.join(DATA_FOLDER, "raw")
TRAIN_RAW_FOLDER = os.path.join(DATA_FOLDER, "train_raw")
TEST_RAW_FOLDER = os.path.join(DATA_FOLDER, "test_raw")
TEST_PROCESSED_FOLDER = os.path.join(DATA_FOLDER, "test_processed")
PREVIEW_FOLDER = os.path.join(DATA_FOLDER, "preview")

# Processing folders (train only - after train/test split)
CONVERTED_FOLDER = os.path.join(DATA_FOLDER, "converted")
PREPROCESSED_FOLDER = os.path.join(DATA_FOLDER, "preprocessed")
FACES_DETECTED_FOLDER = os.path.join(DATA_FOLDER, "faces_detected")
FINAL_PROCESSED_FOLDER = os.path.join(DATA_FOLDER, "final_processed")
AUGMENTED_FOLDER = os.path.join(DATA_FOLDER, "augmented")

# Models folder 
MODELS_FOLDER = os.path.join("..", "models")

# Preprocessing settings
FACE_PADDING_RATIO = 0.2  # 20% padding around detected faces
OUTPUT_SIZE = (128, 128)  # Final size for preprocessed face images
CLAHE_CLIP_LIMIT = 2.0  # CLAHE clip limit for contrast enhancement
CLAHE_GRID_SIZE = (8, 8)  # CLAHE grid size for local enhancement
BLUR_THRESHOLD = 20      # Laplacian variance threshold, used for monitoring only

# Detection settings
DETECTION_SCALE_FACTOR = 0.25  # Scale factor for faster detection (1/4 size)
DETECTION_MODEL = "hog"  # Face detection model: 'hog' for speed, 'cnn' for accuracy

# Image conversion settings
IMAGE_QUALITY = 95  # JPG quality 
MAX_IMAGE_SIZE = (1024, 1024)  # Max size for converted images

# Display settings
PREVIEW_GRID_COLS = 4  # Columns in preview grids
FIGURE_SIZE = (15, 10)  # Default matplotlib figure size

# %%
# === CREATE DATASET FOLDERS ===
# Sync person folders from data/raw so people is always exactly the same as raw.

print("Creating full dataset folder structure...")
print("=" * 55)

# Top-level folders
top_level_folders = [
    DATA_FOLDER,
    RAW_FOLDER,
    TRAIN_RAW_FOLDER,
    TEST_RAW_FOLDER,
    TEST_PROCESSED_FOLDER,
    PREVIEW_FOLDER,
    MODELS_FOLDER,
]
for folder in top_level_folders:
    os.makedirs(folder, exist_ok=True)

# Processing stage folders (train only - created after train/test split)
processing_stage_folders = [
    CONVERTED_FOLDER,
    PREPROCESSED_FOLDER,
    FACES_DETECTED_FOLDER,
    FINAL_PROCESSED_FOLDER,
    AUGMENTED_FOLDER,
]
for folder in processing_stage_folders:
    os.makedirs(folder, exist_ok=True)

# Read people directly from raw folder (single source of truth)
people = sorted([
    person for person in os.listdir(RAW_FOLDER)
    if os.path.isdir(os.path.join(RAW_FOLDER, person))
])

if not people:
    print(f"⚠️ No person folders found in {RAW_FOLDER}")
    print("   Add person folders to data/raw first, then re-run this cell.")
else:
    print(f"📁 Synced people from raw: {len(people)}")

    # Create person subfolders in train_raw and test_raw (after split)
    for person in people:
        os.makedirs(os.path.join(TRAIN_RAW_FOLDER, person), exist_ok=True)
        os.makedirs(os.path.join(TEST_RAW_FOLDER, person), exist_ok=True)
        os.makedirs(os.path.join(TEST_PROCESSED_FOLDER, person), exist_ok=True)

    # Create person subfolders in processing stages (train only)
    for person in people:
        for base in processing_stage_folders:
            os.makedirs(os.path.join(base, person), exist_ok=True)

# Preview subfolders used by later visualization/evaluation cells
preview_subfolders = [
    os.path.join(PREVIEW_FOLDER, "augmentation_samples"),
    os.path.join(PREVIEW_FOLDER, "evaluation_results"),
]
for folder in preview_subfolders:
    os.makedirs(folder, exist_ok=True)
# Out:
# Creating full dataset folder structure...
# =======================================================
# 📁 Synced people from raw: 21

# %% [markdown]
# # Dataset Analysis

# %%
def analyze_dataset():
    """Analyze the current raw dataset structure and contents."""

    if not os.path.exists(RAW_FOLDER):
        print(f"❌ Raw folder not found: {RAW_FOLDER}")
        return False

    print("🔍 DATASET ANALYSIS")
    print("=" * 50)

    person_dirs = [f for f in os.listdir(RAW_FOLDER)
                   if os.path.isdir(os.path.join(RAW_FOLDER, f))]

    if not person_dirs:
        print(f"❌ No person folders found in {RAW_FOLDER}")
        print("   Create a subfolder per person and add their photos.")
        return False

    total_images = 0
    format_stats = {}
    person_stats = {}

    print(f"📁 Found {len(person_dirs)} people in data/raw/:\n")

    for person in sorted(person_dirs):
        person_path = os.path.join(RAW_FOLDER, person)
        image_files = [f for f in os.listdir(person_path)
                       if os.path.isfile(os.path.join(person_path, f)) and
                       Path(f).suffix.lower() in {'.jpg', '.jpeg', '.png', '.heic'}]

        person_stats[person] = len(image_files)
        total_images += len(image_files)

        for img in image_files:
            ext = Path(img).suffix.lower()
            format_stats[ext] = format_stats.get(ext, 0) + 1

        flag = "✅" if len(image_files) >= 5 else ("⚠️" if len(image_files) > 0 else "❌")
        print(f"  {flag} {person}: {len(image_files)} images")

    print(f"\n📊 SUMMARY:")
    print(f"  • Total people:        {len(person_dirs)}")
    print(f"  • Total images:        {total_images}")
    if person_dirs:
        print(f"  • Avg per person:      {total_images / len(person_dirs):.1f}")
        min_person = min(person_stats, key=person_stats.get)
        max_person = max(person_stats, key=person_stats.get)
        print(f"  • Min: {person_stats[min_person]} ({min_person})")
        print(f"  • Max: {person_stats[max_person]} ({max_person})")

    print(f"\n📂 PROCESSING FOLDERS STATUS:")
    pipeline_folders = [
        ('converted',       CONVERTED_FOLDER),
        ('preprocessed',    PREPROCESSED_FOLDER),
        ('final_processed', FINAL_PROCESSED_FOLDER),
        ('test_processed',  TEST_PROCESSED_FOLDER),
        ('augmented',       AUGMENTED_FOLDER),
    ]
    for name, path in pipeline_folders:
        if os.path.exists(path):
            count = sum(
                len([f for f in os.listdir(os.path.join(path, p))
                     if Path(f).suffix.lower() in {'.jpg', '.jpeg', '.png'}])
                for p in os.listdir(path)
                if os.path.isdir(os.path.join(path, p))
            )
            print(f"  ✅ {name}: {count} files")
        else:
            print(f"  ❌ {name}: not created yet")

    people_with_few = [p for p, c in person_stats.items() if c < 5]
    if people_with_few:
        print(f"\n⚠️  People with fewer than 5 images (add more photos):")
        for p in people_with_few:
            print(f"     • {p}: {person_stats[p]} image(s)")

    return True

# Run the analysis
analyze_dataset()
# Out:
# 🔍 DATASET ANALYSIS
# ==================================================
# 📁 Found 21 people in data/raw/:
#
#   ✅ Dr.Nurul: 11 images
#   ✅ benjamin: 41 images
#   ✅ chern_tak: 36 images
#   ✅ chillien: 14 images
#   ✅ daniel: 84 images
#   ✅ dylan: 40 images
#   ✅ han_soon: 11 images
#   ✅ harry: 10 images
#   ✅ isaac: 10 images
#   ✅ jing_ang: 9 images
#   ✅ jun_wei: 9 images
#   ✅ kang_kai: 16 images
#   ✅ marion: 11 images
#   ✅ qi_xuan: 11 images
#   ✅ shuang_quan: 75 images
#   ✅ wee_xuan: 16 images
#   ✅ xiang_yue: 14 images
#   ✅ xu_sheng: 23 images
#   ✅ yoke_hong: 49 images
#   ✅ yong_kang: 13 images
#   ✅ zi_herng: 11 images
#
# 📊 SUMMARY:
#   • Total people:        21
#   • Total images:        514
#   • Avg per person:      24.5
#   • Min: 9 (jing_ang)
#   • Max: 84 (daniel)
#
# 📂 PROCESSING FOLDERS STATUS:
#   ✅ converted: 361 files
#   ✅ preprocessed: 361 files
#   ✅ final_processed: 0 files
#   ✅ test_processed: 0 files
#   ✅ augmented: 0 files
# True

# %% [markdown]
# # Step 1: Image Conversion, Standardization & Train/Test Split

# %%
def convert_heic_to_jpg(input_path, output_path, quality=95):
    """Convert HEIC file to JPG"""
    if not HAS_HEIF_SUPPORT:
        print(f"⚠️ HEIC support not available. Skipping {input_path}")
        return False

    try:
        with Image.open(input_path) as image:
            if image.mode != 'RGB':
                image = image.convert('RGB')
            image.save(output_path, 'JPEG', quality=quality, optimize=True)
            return True
    except Exception as e:
        print(f"❌ Error converting {input_path}: {e}")
        return False


def standardize_image(input_path, output_path, target_size=MAX_IMAGE_SIZE, quality=IMAGE_QUALITY):
    """Standardize image size and format"""
    try:
        with Image.open(input_path) as image:
            if image.mode != 'RGB':
                image = image.convert('RGB')
            image = ImageOps.fit(image, target_size, Image.Resampling.LANCZOS)
            image.save(output_path, 'JPEG', quality=quality, optimize=True)
            return True
    except Exception as e:
        print(f"❌ Error standardizing {input_path}: {e}")
        return False


def convert_all_images(test_ratio=0.3, random_seed=42):
    """Standardize all images and split train/test without Step-1 per-person cap."""

    print("🔄 STARTING IMAGE CONVERSION + SPLIT")
    print("=" * 72)

    required_folders = [RAW_FOLDER, CONVERTED_FOLDER, TRAIN_RAW_FOLDER, TEST_RAW_FOLDER]
    for folder in required_folders:
        if not os.path.exists(folder):
            print(f"❌ Required folder not found: {folder}")
            return 0, 0, 0, 0

    person_dirs = [
        f for f in os.listdir(RAW_FOLDER)
        if os.path.isdir(os.path.join(RAW_FOLDER, f))
    ]
    if not person_dirs:
        print(f"❌ No person folders found in {RAW_FOLDER}")
        return 0, 0, 0, 0

    total_converted = 0
    total_failed = 0
    total_train = 0
    total_test = 0

    image_extensions = {'.jpg', '.jpeg', '.png', '.heic', '.JPG', '.JPEG', '.PNG', '.HEIC'}

    for person_idx, person in enumerate(sorted(person_dirs)):
        person_input_path = os.path.join(RAW_FOLDER, person)
        person_converted_path = os.path.join(CONVERTED_FOLDER, person)
        person_train_raw_path = os.path.join(TRAIN_RAW_FOLDER, person)
        person_test_raw_path = os.path.join(TEST_RAW_FOLDER, person)

        os.makedirs(person_converted_path, exist_ok=True)
        os.makedirs(person_train_raw_path, exist_ok=True)
        os.makedirs(person_test_raw_path, exist_ok=True)

        for out_folder in [person_converted_path, person_train_raw_path, person_test_raw_path]:
            old_files = [
                f for f in os.listdir(out_folder)
                if os.path.isfile(os.path.join(out_folder, f)) and Path(f).suffix in image_extensions
            ]
            for old_file in old_files:
                os.remove(os.path.join(out_folder, old_file))

        image_files = [
            f for f in os.listdir(person_input_path)
            if os.path.isfile(os.path.join(person_input_path, f)) and Path(f).suffix in image_extensions
        ]

        if not image_files:
            print(f"\n👤 {person}: no images found, skipped")
            continue

        print(f"\n👤 Processing {person} ({len(image_files)} raw images):")

        standardized_pool = []
        with tempfile.TemporaryDirectory() as temp_dir:
            # 1) Standardize first.
            for filename in sorted(image_files):
                input_file = os.path.join(person_input_path, filename)
                temp_output = os.path.join(temp_dir, f"{Path(filename).stem}_std.jpg")
                is_heic = Path(filename).suffix.lower() == '.heic'

                if is_heic:
                    success = convert_heic_to_jpg(input_file, temp_output, IMAGE_QUALITY)
                    if success and os.path.exists(temp_output):
                        success = standardize_image(temp_output, temp_output)
                else:
                    success = standardize_image(input_file, temp_output)

                if success and os.path.exists(temp_output):
                    standardized_pool.append((filename, temp_output))
                else:
                    print(f"  ❌ Failed (standardize): {filename}")
                    total_failed += 1

            if not standardized_pool:
                print("  ⚠️ No valid standardized images.")
                continue

            # 2) Split into train/test.
            rng = np.random.RandomState(random_seed + person_idx)
            rng.shuffle(standardized_pool)

            if len(standardized_pool) == 1:
                test_count = 0
            else:
                test_count = max(1, int(round(len(standardized_pool) * test_ratio)))
                test_count = min(test_count, len(standardized_pool) - 1)

            test_items = standardized_pool[:test_count]
            train_items = standardized_pool[test_count:]

            # Save standardized JPG test outputs.
            test_index = 1
            for raw_filename, standardized_file in test_items:
                test_output_filename = f"{person}_test_{test_index:03d}.jpg"
                shutil.copy2(
                    standardized_file,
                    os.path.join(person_test_raw_path, test_output_filename),
                )
                test_index += 1
                total_test += 1
                print(f"  🧪 TEST  {raw_filename} → {test_output_filename}")

            if not train_items:
                print(f"  ⚠️ No train images left after split.")
                print(f"  📊 {person} final split: train=0, test={len(test_items)}")
                continue

            # No cap here: keep all train items.
            final_train_items = train_items
            print(f"  🎯 Train kept: {len(final_train_items)}")

            # Save train_raw + converted from train selection.
            converted_index = 1
            for raw_filename, standardized_file in final_train_items:
                shutil.copy2(
                    os.path.join(person_input_path, raw_filename),
                    os.path.join(person_train_raw_path, raw_filename),
                )
                total_train += 1

                output_filename = f"{person}_{converted_index:03d}.jpg"
                output_file = os.path.join(person_converted_path, output_filename)
                shutil.copy2(standardized_file, output_file)
                converted_index += 1
                total_converted += 1
                print(f"  ✅ TRAIN {raw_filename} → {output_filename}")

            print(f"  📊 {person} final split: train={len(final_train_items)}, test={len(test_items)}")

    print(f"\n✨ CONVERSION + SPLIT COMPLETE!")
    print(f"  ✅ Converted train images: {total_converted}")
    print(f"  🏋️ Train raw images:       {total_train}")
    print(f"  🧪 Test raw images:        {total_test}")
    print(f"  ❌ Failed:                 {total_failed}")
    print(f"  📁 Converted (train): {CONVERTED_FOLDER}")
    print(f"  📁 Train raw:         {TRAIN_RAW_FOLDER}")
    print(f"  📁 Test raw:          {TEST_RAW_FOLDER}")

    return total_converted, total_train, total_test, total_failed


conversionAndSplitConversion_stats = convert_all_images(test_ratio=0.3, random_seed=42)
# Out:
# 🔄 STARTING IMAGE CONVERSION + SPLIT
# ========================================================================
#
# 👤 Processing Dr.Nurul (11 raw images):
#   🧪 TEST  IMG_5228.HEIC → Dr.Nurul_test_001.jpg
#   🧪 TEST  IMG_5222.HEIC → Dr.Nurul_test_002.jpg
#   🧪 TEST  IMG_5232.HEIC → Dr.Nurul_test_003.jpg
#   🎯 Train kept: 8
#   ✅ TRAIN IMG_5233.HEIC → Dr.Nurul_001.jpg
#   ✅ TRAIN IMG_5225.HEIC → Dr.Nurul_002.jpg
#   ✅ TRAIN IMG_5223.HEIC → Dr.Nurul_003.jpg
#   ✅ TRAIN IMG_5231.HEIC → Dr.Nurul_004.jpg
#   ✅ TRAIN IMG_5227.HEIC → Dr.Nurul_005.jpg
#   ✅ TRAIN IMG_5230.HEIC → Dr.Nurul_006.jpg
#   ✅ TRAIN IMG_5226.HEIC → Dr.Nurul_007.jpg
#   ✅ TRAIN IMG_5229.HEIC → Dr.Nurul_008.jpg
#   📊 Dr.Nurul final split: train=8, test=3
#
# 👤 Processing benjamin (41 raw images):
#   🧪 TEST  IMG_5272.HEIC → benjamin_test_001.jpg
#   🧪 TEST  IMG_1931.JPG → benjamin_test_002.jpg
#   🧪 TEST  IMG_5278.HEIC → benjamin_test_003.jpg
#   🧪 TEST  IMG_5284.HEIC → benjamin_test_004.jpg
#   🧪 TEST  IMG_1932.JPG → benjamin_test_005.jpg
#   🧪 TEST  IMG_5282.HEIC → benjamin_test_006.jpg
#   🧪 TEST  IMG_1933.JPG → benjamin_test_007.jpg
#   🧪 TEST  IMG_8774.HEIC → benjamin_test_008.jpg
#   🧪 TEST  IMG_5280.HEIC → benjamin_test_009.jpg
#   🧪 TEST  IMG_E1933.JPG → benjamin_test_010.jpg
#   🧪 TEST  IMG_5267.HEIC → benjamin_test_011.jpg
#   🧪 TEST  IMG_5271.HEIC → benjamin_test_012.jpg
#   🎯 Train kept: 29
#   ✅ TRAIN IMG_5268.HEIC → benjamin_001.jpg
#   ✅ TRAIN IMG_E1924.JPG → benjamin_002.jpg
#   ✅ TRAIN IMG_E1931.JPG → benjamin_003.jpg
#   ✅ TRAIN IMG_1934.JPG → benjamin_004.jpg
#   ✅ TRAIN IMG_5270.HEIC → benjamin_005.jpg
#   ✅ TRAIN IMG_E1932.JPG → benjamin_006.jpg
#   ✅ TRAIN IMG_5277.HEIC → benjamin_007.jpg
#   ✅ TRAIN IMG_E8773.HEIC → benjamin_008.jpg
#   ✅ TRAIN IMG_E1926.JPG → benjamin_009.jpg
#   ✅ TRAIN IMG_E1925.JPG → benjamin_010.jpg
#   ✅ TRAIN IMG_8773.HEIC → benjamin_011.jpg
#   ✅ TRAIN IMG_E1929.JPG → benjamin_012.jpg
#   ✅ TRAIN IMG_5273.HEIC → benjamin_013.jpg
#   ✅ TRAIN IMG_1925.JPG → benjamin_014.jpg
#   ✅ TRAIN IMG_5283.HEIC → benjamin_015.jpg
#   ✅ TRAIN IMG_5269.HEIC → benjamin_016.jpg
#   ✅ TRAIN IMG_E1930.JPG → benjamin_017.jpg
#   ✅ TRAIN IMG_5276.HEIC → benjamin_018.jpg
#   ✅ TRAIN IMG_1929.JPG → benjamin_019.jpg
#   ✅ TRAIN IMG_E1934.JPG → benjamin_020.jpg
#   ✅ TRAIN IMG_5281.HEIC → benjamin_021.jpg
#   ✅ TRAIN IMG_8775.HEIC → benjamin_022.jpg
#   ✅ TRAIN IMG_1926.JPG → benjamin_023.jpg
#   ✅ TRAIN IMG_5285.HEIC → benjamin_024.jpg
#   ✅ TRAIN IMG_5275.HEIC → benjamin_025.jpg
#   ✅ TRAIN IMG_5274.HEIC → benjamin_026.jpg
#   ✅ TRAIN IMG_5279.HEIC → benjamin_027.jpg
#   ✅ TRAIN IMG_1924.JPG → benjamin_028.jpg
#   ✅ TRAIN IMG_1930.JPG → benjamin_029.jpg
#   📊 benjamin final split: train=29, test=12
#
# 👤 Processing chern_tak (36 raw images):
#   🧪 TEST  IMG_0983.HEIC → chern_tak_test_001.jpg
#   🧪 TEST  IMG_0743.HEIC → chern_tak_test_002.jpg
#   🧪 TEST  IMG_0745.HEIC → chern_tak_test_003.jpg
#   🧪 TEST  IMG_9323.PNG → chern_tak_test_004.jpg
#   🧪 TEST  IMG_0982.HEIC → chern_tak_test_005.jpg
#   🧪 TEST  IMG_9327.PNG → chern_tak_test_006.jpg
#   🧪 TEST  IMG_0746.HEIC → chern_tak_test_007.jpg
#   🧪 TEST  IMG_8280.PNG → chern_tak_test_008.jpg
#   🧪 TEST  IJES7702.JPG → chern_tak_test_009.jpg
#   🧪 TEST  IMG_1556.HEIC → chern_tak_test_010.jpg
#   🧪 TEST  BFOQ6507.JPG → chern_tak_test_011.jpg
#   🎯 Train kept: 25
#   ✅ TRAIN IMG_1558.HEIC → chern_tak_001.jpg
#   ✅ TRAIN IMG_0739.HEIC → chern_tak_002.jpg
#   ✅ TRAIN IMG_0984.HEIC → chern_tak_003.jpg
#   ✅ TRAIN IMG_1563.HEIC → chern_tak_004.jpg
#   ✅ TRAIN IMG_0742.HEIC → chern_tak_005.jpg
#   ✅ TRAIN IMG_0980.HEIC → chern_tak_006.jpg
#   ✅ TRAIN GGDI6673.JPG → chern_tak_007.jpg
#   ✅ TRAIN IMG_0738.HEIC → chern_tak_008.jpg
#   ✅ TRAIN IMG_0747.HEIC → chern_tak_009.jpg
#   ✅ TRAIN IMG_0740.HEIC → chern_tak_010.jpg
#   ✅ TRAIN IMG_1562.HEIC → chern_tak_011.jpg
#   ✅ TRAIN IMG_2621.HEIC → chern_tak_012.jpg
#   ✅ TRAIN IMG_0741.HEIC → chern_tak_013.jpg
#   ✅ TRAIN IMG_9324.PNG → chern_tak_014.jpg
#   ✅ TRAIN IMG_1559.HEIC → chern_tak_015.jpg
#   ✅ TRAIN IMG_2609.HEIC → chern_tak_016.jpg
#   ✅ TRAIN IMG_1560.HEIC → chern_tak_017.jpg
#   ✅ TRAIN IMG_1561.HEIC → chern_tak_018.jpg
#   ✅ TRAIN IMG_0744.HEIC → chern_tak_019.jpg
#   ✅ TRAIN IMG_0981.HEIC → chern_tak_020.jpg
#   ✅ TRAIN WhatsApp Image 2026-02-24 at 9.43.57 AM.jpeg → chern_tak_021.jpg
#   ✅ TRAIN WhatsApp Image 2026-02-24 at 9.45.44 AM.jpeg → chern_tak_022.jpg
#   ✅ TRAIN IMG_9326.PNG → chern_tak_023.jpg
#   ✅ TRAIN IMG_0737.HEIC → chern_tak_024.jpg
#   ✅ TRAIN IMG_1557.HEIC → chern_tak_025.jpg
#   📊 chern_tak final split: train=25, test=11
#
# 👤 Processing chillien (14 raw images):
#   🧪 TEST  photo_33_2026-03-09_19-08-19.jpg → chillien_test_001.jpg
#   🧪 TEST  photo_32_2026-03-09_19-08-19.jpg → chillien_test_002.jpg
#   🧪 TEST  photo_30_2026-03-09_19-08-19.jpg → chillien_test_003.jpg
#   🧪 TEST  IMG_8359.HEIC → chillien_test_004.jpg
#   🎯 Train kept: 10
#   ✅ TRAIN photo_34_2026-03-09_19-08-19.jpg → chillien_001.jpg
#   ✅ TRAIN photo_31_2026-03-09_19-08-19.jpg → chillien_002.jpg
#   ✅ TRAIN photo_37_2026-03-09_19-08-19.jpg → chillien_003.jpg
#   ✅ TRAIN IMG_8295.HEIC → chillien_004.jpg
#   ✅ TRAIN IMG_8592.HEIC → chillien_005.jpg
#   ✅ TRAIN photo_36_2026-03-09_19-08-19.jpg → chillien_006.jpg
#   ✅ TRAIN WhatsApp Image 2026-02-24 at 9.45.45 AM.jpeg → chillien_007.jpg
#   ✅ TRAIN IMG_1600.HEIC → chillien_008.jpg
#   ✅ TRAIN IMG_8499.HEIC → chillien_009.jpg
#   ✅ TRAIN photo_35_2026-03-09_19-08-19.jpg → chillien_010.jpg
#   📊 chillien final split: train=10, test=4
#
# 👤 Processing daniel (84 raw images):
#   🧪 TEST  IMG_5660.HEIC → daniel_test_001.jpg
#   🧪 TEST  IMG_2382.HEIC → daniel_test_002.jpg
#   🧪 TEST  IMG_8271.HEIC → daniel_test_003.jpg
#   🧪 TEST  OYST2923.JPG → daniel_test_004.jpg
#   🧪 TEST  IMG_3378.HEIC → daniel_test_005.jpg
#   🧪 TEST  IMG_5648.HEIC → daniel_test_006.jpg
#   🧪 TEST  IMG_2614.HEIC → daniel_test_007.jpg
#   🧪 TEST  IMG_9747.PNG → daniel_test_008.jpg
#   🧪 TEST  IMG_5647.HEIC → daniel_test_009.jpg
#   🧪 TEST  WhatsApp Image 2026-02-24 at 9.45.30 AM.jpeg → daniel_test_010.jpg
#   🧪 TEST  IMG_3376.HEIC → daniel_test_011.jpg
#   🧪 TEST  IMG_5656.HEIC → daniel_test_012.jpg
#   🧪 TEST  IMG_E8306.JPG → daniel_test_013.jpg
#   🧪 TEST  IMG_5652.HEIC → daniel_test_014.jpg
#   🧪 TEST  IMG_5662.HEIC → daniel_test_015.jpg
#   🧪 TEST  IMG_5658.HEIC → daniel_test_016.jpg
#   🧪 TEST  IMG_5659.HEIC → daniel_test_017.jpg
#   🧪 TEST  IMG_8468.HEIC → daniel_test_018.jpg
#   🧪 TEST  IMG_5665.HEIC → daniel_test_019.jpg
#   🧪 TEST  IMG_8201.HEIC → daniel_test_020.jpg
#   🧪 TEST  IMG_8205.HEIC → daniel_test_021.jpg
#   🧪 TEST  IMG_1609.HEIC → daniel_test_022.jpg
#   🧪 TEST  IMG_5643.HEIC → daniel_test_023.jpg
#   🧪 TEST  IMG_8165.HEIC → daniel_test_024.jpg
#   🧪 TEST  IMG_9748.PNG → daniel_test_025.jpg
#   🎯 Train kept: 59
#   ✅ TRAIN IMG_5644.HEIC → daniel_001.jpg
#   ✅ TRAIN IMG_8524.HEIC → daniel_002.jpg
#   ✅ TRAIN IMG_5664.HEIC → daniel_003.jpg
#   ✅ TRAIN IMG_3377.HEIC → daniel_004.jpg
#   ✅ TRAIN IMG_9551.HEIC → daniel_005.jpg
#   ✅ TRAIN IMG_1607.HEIC → daniel_006.jpg
#   ✅ TRAIN IMG_9554.HEIC → daniel_007.jpg
#   ✅ TRAIN IMG_1606.HEIC → daniel_008.jpg
#   ✅ TRAIN IMG_5657.HEIC → daniel_009.jpg
#   ✅ TRAIN IMG_5667.HEIC → daniel_010.jpg
#   ✅ TRAIN IMG_1612.HEIC → daniel_011.jpg
#   ✅ TRAIN IMG_5649.HEIC → daniel_012.jpg
#   ✅ TRAIN IMG_1610.HEIC → daniel_013.jpg
#   ✅ TRAIN IMG_9749.PNG → daniel_014.jpg
#   ✅ TRAIN DXRY6026.JPG → daniel_015.jpg
#   ✅ TRAIN IMG_5661.HEIC → daniel_016.jpg
#   ✅ TRAIN IMG_5668.HEIC → daniel_017.jpg
#   ✅ TRAIN IMG_5669.HEIC → daniel_018.jpg
#   ✅ TRAIN IMG_8274.HEIC → daniel_019.jpg
#   ✅ TRAIN IMG_9426.HEIC → daniel_020.jpg
#   ✅ TRAIN IMG_9340.HEIC → daniel_021.jpg
#   ✅ TRAIN IMG_8202.HEIC → daniel_022.jpg
#   ✅ TRAIN IMG_9557.HEIC → daniel_023.jpg
#   ✅ TRAIN IMG_1608.HEIC → daniel_024.jpg
#   ✅ TRAIN IMG_5640.HEIC → daniel_025.jpg
#   ✅ TRAIN IMG_8264.HEIC → daniel_026.jpg
#   ✅ TRAIN IMG_5646.HEIC → daniel_027.jpg
#   ✅ TRAIN IMG_9553.HEIC → daniel_028.jpg
#   ✅ TRAIN IMG_3384.HEIC → daniel_029.jpg
#   ✅ TRAIN IMG_8273.HEIC → daniel_030.jpg
#   ✅ TRAIN IMG_5651.HEIC → daniel_031.jpg
#   ✅ TRAIN ENEP8790.JPG → daniel_032.jpg
#   ✅ TRAIN IMG_2615.HEIC → daniel_033.jpg
#   ✅ TRAIN IMG_1611.HEIC → daniel_034.jpg
#   ✅ TRAIN RXAT7883.JPG → daniel_035.jpg
#   ✅ TRAIN IMG_8206.HEIC → daniel_036.jpg
#   ✅ TRAIN IMG_8424.HEIC → daniel_037.jpg
#   ✅ TRAIN IMG_5666.HEIC → daniel_038.jpg
#   ✅ TRAIN IMG_9374.JPG → daniel_039.jpg
#   ✅ TRAIN IMG_8166.HEIC → daniel_040.jpg
#   ✅ TRAIN UMGR9316.HEIC → daniel_041.jpg
#   ✅ TRAIN IMG_9558.HEIC → daniel_042.jpg
#   ✅ TRAIN IMG_5653.HEIC → daniel_043.jpg
#   ✅ TRAIN IMG_8362.HEIC → daniel_044.jpg
#   ✅ TRAIN IMG_5645.HEIC → daniel_045.jpg
#   ✅ TRAIN IMG_8272.HEIC → daniel_046.jpg
#   ✅ TRAIN IMG_5654.HEIC → daniel_047.jpg
#   ✅ TRAIN IMG_5655.HEIC → daniel_048.jpg
#   ✅ TRAIN IMG_9555.HEIC → daniel_049.jpg
#   ✅ TRAIN IMG_0627.HEIC → daniel_050.jpg
#   ✅ TRAIN IMG_5650.HEIC → daniel_051.jpg
#   ✅ TRAIN IMG_8363.HEIC → daniel_052.jpg
#   ✅ TRAIN IMG_9746.PNG → daniel_053.jpg
#   ✅ TRAIN IMG_5641.HEIC → daniel_054.jpg
#   ✅ TRAIN IMG_5642.HEIC → daniel_055.jpg
#   ✅ TRAIN IMG_8275.HEIC → daniel_056.jpg
#   ✅ TRAIN IMG_5663.HEIC → daniel_057.jpg
#   ✅ TRAIN IMG_9552.HEIC → daniel_058.jpg
#   ✅ TRAIN IMG_8364.HEIC → daniel_059.jpg
#   📊 daniel final split: train=59, test=25
#
# 👤 Processing dylan (40 raw images):
#   🧪 TEST  IMG_5184.HEIC → dylan_test_001.jpg
#   🧪 TEST  IMG_5200.HEIC → dylan_test_002.jpg
#   🧪 TEST  IMG_5191.HEIC → dylan_test_003.jpg
#   🧪 TEST  IMG_5194.HEIC → dylan_test_004.jpg
#   🧪 TEST  IMG_5208.HEIC → dylan_test_005.jpg
#   🧪 TEST  IMG_5180.HEIC → dylan_test_006.jpg
#   🧪 TEST  IMG_5175.HEIC → dylan_test_007.jpg
#   🧪 TEST  IMG_5185.HEIC → dylan_test_008.jpg
#   🧪 TEST  IMG_5173.HEIC → dylan_test_009.jpg
#   🧪 TEST  IMG_5174.HEIC → dylan_test_010.jpg
#   🧪 TEST  IMG_5198.HEIC → dylan_test_011.jpg
#   🧪 TEST  IMG_5199.HEIC → dylan_test_012.jpg
#   🎯 Train kept: 28
#   ✅ TRAIN IMG_5170.HEIC → dylan_001.jpg
#   ✅ TRAIN IMG_5172.HEIC → dylan_002.jpg
#   ✅ TRAIN IMG_5182.HEIC → dylan_003.jpg
#   ✅ TRAIN IMG_5189.HEIC → dylan_004.jpg
#   ✅ TRAIN IMG_5202.HEIC → dylan_005.jpg
#   ✅ TRAIN IMG_5197.HEIC → dylan_006.jpg
#   ✅ TRAIN IMG_5192.HEIC → dylan_007.jpg
#   ✅ TRAIN IMG_5195.HEIC → dylan_008.jpg
#   ✅ TRAIN IMG_5179.HEIC → dylan_009.jpg
#   ✅ TRAIN IMG_5205.HEIC → dylan_010.jpg
#   ✅ TRAIN IMG_5190.HEIC → dylan_011.jpg
#   ✅ TRAIN IMG_5171.HEIC → dylan_012.jpg
#   ✅ TRAIN IMG_5181.HEIC → dylan_013.jpg
#   ✅ TRAIN IMG_5196.HEIC → dylan_014.jpg
#   ✅ TRAIN IMG_5188.HEIC → dylan_015.jpg
#   ✅ TRAIN IMG_5203.HEIC → dylan_016.jpg
#   ✅ TRAIN IMG_5187.HEIC → dylan_017.jpg
#   ✅ TRAIN IMG_5183.HEIC → dylan_018.jpg
#   ✅ TRAIN IMG_5201.HEIC → dylan_019.jpg
#   ✅ TRAIN IMG_5207.HEIC → dylan_020.jpg
#   ✅ TRAIN IMG_5204.HEIC → dylan_021.jpg
#   ✅ TRAIN IMG_5193.HEIC → dylan_022.jpg
#   ✅ TRAIN IMG_5186.HEIC → dylan_023.jpg
#   ✅ TRAIN IMG_5206.HEIC → dylan_024.jpg
#   ✅ TRAIN IMG_5178.HEIC → dylan_025.jpg
#   ✅ TRAIN IMG_5209.HEIC → dylan_026.jpg
#   ✅ TRAIN IMG_5176.HEIC → dylan_027.jpg
#   ✅ TRAIN IMG_5177.HEIC → dylan_028.jpg
#   📊 dylan final split: train=28, test=12
#
# 👤 Processing han_soon (11 raw images):
#   🧪 TEST  IMG_8211.HEIC → han_soon_test_001.jpg
#   🧪 TEST  IMG_5219.HEIC → han_soon_test_002.jpg
#   🧪 TEST  IMG_5218.HEIC → han_soon_test_003.jpg
#   🎯 Train kept: 8
#   ✅ TRAIN IMG_5214.HEIC → han_soon_001.jpg
#   ✅ TRAIN IMG_5217.HEIC → han_soon_002.jpg
#   ✅ TRAIN WhatsApp Image 2026-02-24 at 9.45.43 AM.jpeg → han_soon_003.jpg
#   ✅ TRAIN WhatsApp Image 2026-02-24 at 9.44.19 AM.jpeg → han_soon_004.jpg
#   ✅ TRAIN IMG_5216.HEIC → han_soon_005.jpg
#   ✅ TRAIN IMG_5212.HEIC → han_soon_006.jpg
#   ✅ TRAIN IMG_5215.HEIC → han_soon_007.jpg
#   ✅ TRAIN IMG_5211.HEIC → han_soon_008.jpg
#   📊 han_soon final split: train=8, test=3
#
# 👤 Processing harry (10 raw images):
#   🧪 TEST  photo_9_2026-03-24_20-29-37.jpg → harry_test_001.jpg
#   🧪 TEST  photo_10_2026-03-24_20-29-37.jpg → harry_test_002.jpg
#   🧪 TEST  photo_3_2026-03-24_20-29-37.jpg → harry_test_003.jpg
#   🎯 Train kept: 7
#   ✅ TRAIN photo_1_2026-03-24_20-29-37.jpg → harry_001.jpg
#   ✅ TRAIN photo_7_2026-03-24_20-29-37.jpg → harry_002.jpg
#   ✅ TRAIN photo_2_2026-03-24_20-29-37.jpg → harry_003.jpg
#   ✅ TRAIN photo_4_2026-03-24_20-29-37.jpg → harry_004.jpg
#   ✅ TRAIN photo_6_2026-03-24_20-29-37.jpg → harry_005.jpg
#   ✅ TRAIN photo_5_2026-03-24_20-29-37.jpg → harry_006.jpg
#   ✅ TRAIN photo_8_2026-03-24_20-29-37.jpg → harry_007.jpg
#   📊 harry final split: train=7, test=3
#
# 👤 Processing isaac (10 raw images):
#   🧪 TEST  IMG_5492.HEIC → isaac_test_001.jpg
#   🧪 TEST  IMG_5493.HEIC → isaac_test_002.jpg
#   🧪 TEST  IMG_5491.HEIC → isaac_test_003.jpg
#   🎯 Train kept: 7
#   ✅ TRAIN IMG_5487.HEIC → isaac_001.jpg
#   ✅ TRAIN IMG_5489.HEIC → isaac_002.jpg
#   ✅ TRAIN IMG_5486.HEIC → isaac_003.jpg
#   ✅ TRAIN IMG_5490.HEIC → isaac_004.jpg
#   ✅ TRAIN IMG_5488.HEIC → isaac_005.jpg
#   ✅ TRAIN IMG_5494.HEIC → isaac_006.jpg
#   ✅ TRAIN IMG_5485.HEIC → isaac_007.jpg
#   📊 isaac final split: train=7, test=3
#
# 👤 Processing jing_ang (9 raw images):
#   🧪 TEST  IMG_5498.HEIC → jing_ang_test_001.jpg
#   🧪 TEST  IMG_5499.HEIC → jing_ang_test_002.jpg
#   🧪 TEST  IMG_5497.HEIC → jing_ang_test_003.jpg
#   🎯 Train kept: 6
#   ✅ TRAIN IMG_5501.HEIC → jing_ang_001.jpg
#   ✅ TRAIN IMG_5502.HEIC → jing_ang_002.jpg
#   ✅ TRAIN IMG_5503.HEIC → jing_ang_003.jpg
#   ✅ TRAIN IMG_5496.HEIC → jing_ang_004.jpg
#   ✅ TRAIN IMG_5495.HEIC → jing_ang_005.jpg
#   ✅ TRAIN IMG_5500.HEIC → jing_ang_006.jpg
#   📊 jing_ang final split: train=6, test=3
#
# 👤 Processing jun_wei (9 raw images):
#   🧪 TEST  IMG_5515.HEIC → jun_wei_test_001.jpg
#   🧪 TEST  IMG_5514.HEIC → jun_wei_test_002.jpg
#   🧪 TEST  IMG_5513.HEIC → jun_wei_test_003.jpg
#   🎯 Train kept: 6
#   ✅ TRAIN IMG_5519.HEIC → jun_wei_001.jpg
#   ✅ TRAIN IMG_5520.HEIC → jun_wei_002.jpg
#   ✅ TRAIN IMG_5521.HEIC → jun_wei_003.jpg
#   ✅ TRAIN IMG_5516.HEIC → jun_wei_004.jpg
#   ✅ TRAIN IMG_5517.HEIC → jun_wei_005.jpg
#   ✅ TRAIN IMG_5518.HEIC → jun_wei_006.jpg
#   📊 jun_wei final split: train=6, test=3
#
# 👤 Processing kang_kai (16 raw images):
#   🧪 TEST  IMG_1599.HEIC → kang_kai_test_001.jpg
#   🧪 TEST  photo_21_2026-03-09_19-08-19.jpg → kang_kai_test_002.jpg
#   🧪 TEST  photo_26_2026-03-09_19-08-19.jpg → kang_kai_test_003.jpg
#   🧪 TEST  photo_24_2026-03-09_19-08-19.jpg → kang_kai_test_004.jpg
#   🧪 TEST  IMG_1597.HEIC → kang_kai_test_005.jpg
#   🎯 Train kept: 11
#   ✅ TRAIN photo_29_2026-03-09_19-08-19.jpg → kang_kai_001.jpg
#   ✅ TRAIN IMG_1598.HEIC → kang_kai_002.jpg
#   ✅ TRAIN photo_22_2026-03-09_19-08-19.jpg → kang_kai_003.jpg
#   ✅ TRAIN IMG_1596.HEIC → kang_kai_004.jpg
#   ✅ TRAIN WhatsApp Image 2026-02-24 at 9.45.08 AM.jpeg → kang_kai_005.jpg
#   ✅ TRAIN photo_20_2026-03-09_19-08-19.jpg → kang_kai_006.jpg
#   ✅ TRAIN photo_25_2026-03-09_19-08-19.jpg → kang_kai_007.jpg
#   ✅ TRAIN photo_28_2026-03-09_19-08-19.jpg → kang_kai_008.jpg
#   ✅ TRAIN WhatsApp Image 2026-02-24 at 9.45.43 AM.jpeg → kang_kai_009.jpg
#   ✅ TRAIN photo_27_2026-03-09_19-08-19.jpg → kang_kai_010.jpg
#   ✅ TRAIN photo_23_2026-03-09_19-08-19.jpg → kang_kai_011.jpg
#   📊 kang_kai final split: train=11, test=5
#
# 👤 Processing marion (11 raw images):
#   🧪 TEST  IMG_8160.HEIC → marion_test_001.jpg
#   🧪 TEST  IMG_5507.HEIC → marion_test_002.jpg
#   🧪 TEST  IMG_8159.HEIC → marion_test_003.jpg
#   🎯 Train kept: 8
#   ✅ TRAIN IMG_5508.HEIC → marion_001.jpg
#   ✅ TRAIN IMG_5512.HEIC → marion_002.jpg
#   ✅ TRAIN IMG_5510.HEIC → marion_003.jpg
#   ✅ TRAIN IMG_5504.HEIC → marion_004.jpg
#   ✅ TRAIN IMG_5505.HEIC → marion_005.jpg
#   ✅ TRAIN IMG_5511.HEIC → marion_006.jpg
#   ✅ TRAIN IMG_5506.HEIC → marion_007.jpg
#   ✅ TRAIN IMG_5509.HEIC → marion_008.jpg
#   📊 marion final split: train=8, test=3
#
# 👤 Processing qi_xuan (11 raw images):
#   🧪 TEST  photo_3_2026-03-09_19-08-05.jpg → qi_xuan_test_001.jpg
#   🧪 TEST  WhatsApp Image 2026-02-24 at 9.44.37 AM.jpeg → qi_xuan_test_002.jpg
#   🧪 TEST  photo_1_2026-03-09_19-08-05.jpg → qi_xuan_test_003.jpg
#   🎯 Train kept: 8
#   ✅ TRAIN WhatsApp Image 2026-02-24 at 9.45.41 AM.jpeg → qi_xuan_001.jpg
#   ✅ TRAIN photo_2_2026-03-09_19-08-05.jpg → qi_xuan_002.jpg
#   ✅ TRAIN photo_5_2026-03-09_19-08-05.jpg → qi_xuan_003.jpg
#   ✅ TRAIN photo_8_2026-03-09_19-08-05.jpg → qi_xuan_004.jpg
#   ✅ TRAIN photo_4_2026-03-09_19-08-05.jpg → qi_xuan_005.jpg
#   ✅ TRAIN photo_7_2026-03-09_19-08-05.jpg → qi_xuan_006.jpg
#   ✅ TRAIN photo_6_2026-03-09_19-08-05.jpg → qi_xuan_007.jpg
#   ✅ TRAIN photo_9_2026-03-09_19-08-05.jpg → qi_xuan_008.jpg
#   📊 qi_xuan final split: train=8, test=3
#
# 👤 Processing shuang_quan (75 raw images):
#   🧪 TEST  IMG_5691.HEIC → shuang_quan_test_001.jpg
#   🧪 TEST  IMG_2365.JPG → shuang_quan_test_002.jpg
#   🧪 TEST  IMG_1393.HEIC → shuang_quan_test_003.jpg
#   🧪 TEST  IMG_2367.JPG → shuang_quan_test_004.jpg
#   🧪 TEST  IMG_1455.HEIC → shuang_quan_test_005.jpg
#   🧪 TEST  IMG_8208.HEIC → shuang_quan_test_006.jpg
#   🧪 TEST  IMG_E2364.JPG → shuang_quan_test_007.jpg
#   🧪 TEST  IMG_5699.HEIC → shuang_quan_test_008.jpg
#   🧪 TEST  IMG_0973.HEIC → shuang_quan_test_009.jpg
#   🧪 TEST  IMG_2371.JPG → shuang_quan_test_010.jpg
#   🧪 TEST  IMG_1392.HEIC → shuang_quan_test_011.jpg
#   🧪 TEST  IMG_E2347.JPG → shuang_quan_test_012.jpg
#   🧪 TEST  IMG_E2332.JPG → shuang_quan_test_013.jpg
#   🧪 TEST  IMG_9375.JPG → shuang_quan_test_014.jpg
#   🧪 TEST  IMG_7935.HEIC → shuang_quan_test_015.jpg
#   🧪 TEST  IMG_8236.HEIC → shuang_quan_test_016.jpg
#   🧪 TEST  IMG_5695.HEIC → shuang_quan_test_017.jpg
#   🧪 TEST  DPEG6400.JPG → shuang_quan_test_018.jpg
#   🧪 TEST  IMG_5702.HEIC → shuang_quan_test_019.jpg
#   🧪 TEST  IMG_0931.HEIC → shuang_quan_test_020.jpg
#   🧪 TEST  IMG_2370.JPG → shuang_quan_test_021.jpg
#   🧪 TEST  IMG_E2362.JPG → shuang_quan_test_022.jpg
#   🎯 Train kept: 53
#   ✅ TRAIN IMG_2362.JPG → shuang_quan_001.jpg
#   ✅ TRAIN IMG_5701.HEIC → shuang_quan_002.jpg
#   ✅ TRAIN IMG_E2367.JPG → shuang_quan_003.jpg
#   ✅ TRAIN IMG_8779.HEIC → shuang_quan_004.jpg
#   ✅ TRAIN IMG_8193.HEIC → shuang_quan_005.jpg
#   ✅ TRAIN IMG_E2363.JPG → shuang_quan_006.jpg
#   ✅ TRAIN IMG_9428.HEIC → shuang_quan_007.jpg
#   ✅ TRAIN IMG_E2370.JPG → shuang_quan_008.jpg
#   ✅ TRAIN IMG_2361.JPG → shuang_quan_009.jpg
#   ✅ TRAIN IMG_5690.HEIC → shuang_quan_010.jpg
#   ✅ TRAIN IMG_5694.HEIC → shuang_quan_011.jpg
#   ✅ TRAIN IMG_8463.HEIC → shuang_quan_012.jpg
#   ✅ TRAIN IMG_E2368.JPG → shuang_quan_013.jpg
#   ✅ TRAIN IMG_5683.HEIC → shuang_quan_014.jpg
#   ✅ TRAIN IMG_5682.HEIC → shuang_quan_015.jpg
#   ✅ TRAIN IMG_1454.HEIC → shuang_quan_016.jpg
#   ✅ TRAIN IMG_5687.HEIC → shuang_quan_017.jpg
#   ✅ TRAIN IMG_E2333.JPG → shuang_quan_018.jpg
#   ✅ TRAIN IMG_2364.JPG → shuang_quan_019.jpg
#   ✅ TRAIN IMG_2332.JPG → shuang_quan_020.jpg
#   ✅ TRAIN IMG_E2335.JPG → shuang_quan_021.jpg
#   ✅ TRAIN IMG_0351.HEIC → shuang_quan_022.jpg
#   ✅ TRAIN IMG_E2366.JPG → shuang_quan_023.jpg
#   ✅ TRAIN IMG_0352.HEIC → shuang_quan_024.jpg
#   ✅ TRAIN IMG_5698.HEIC → shuang_quan_025.jpg
#   ✅ TRAIN IMG_0974.HEIC → shuang_quan_026.jpg
#   ✅ TRAIN IMG_2363.JPG → shuang_quan_027.jpg
#   ✅ TRAIN IMG_9431.HEIC → shuang_quan_028.jpg
#   ✅ TRAIN IMG_E2365.JPG → shuang_quan_029.jpg
#   ✅ TRAIN IMG_E2371.JPG → shuang_quan_030.jpg
#   ✅ TRAIN IMG_E2369.JPG → shuang_quan_031.jpg
#   ✅ TRAIN IMG_E2334.JPG → shuang_quan_032.jpg
#   ✅ TRAIN IMG_5692.HEIC → shuang_quan_033.jpg
#   ✅ TRAIN IMG_5681.HEIC → shuang_quan_034.jpg
#   ✅ TRAIN IMG_5685.HEIC → shuang_quan_035.jpg
#   ✅ TRAIN IMG_1456.HEIC → shuang_quan_036.jpg
#   ✅ TRAIN IMG_2369.JPG → shuang_quan_037.jpg
#   ✅ TRAIN IMG_5688.HEIC → shuang_quan_038.jpg
#   ✅ TRAIN IMG_5693.HEIC → shuang_quan_039.jpg
#   ✅ TRAIN IMG_8780.HEIC → shuang_quan_040.jpg
#   ✅ TRAIN IMG_2335.JPG → shuang_quan_041.jpg
#   ✅ TRAIN IMG_5703.HEIC → shuang_quan_042.jpg
#   ✅ TRAIN IMG_1457.HEIC → shuang_quan_043.jpg
#   ✅ TRAIN IMG_5700.HEIC → shuang_quan_044.jpg
#   ✅ TRAIN IMG_1460.HEIC → shuang_quan_045.jpg
#   ✅ TRAIN IMG_2368.JPG → shuang_quan_046.jpg
#   ✅ TRAIN IMG_9427.HEIC → shuang_quan_047.jpg
#   ✅ TRAIN IMG_9429.HEIC → shuang_quan_048.jpg
#   ✅ TRAIN IMG_2366.JPG → shuang_quan_049.jpg
#   ✅ TRAIN IMG_2333.JPG → shuang_quan_050.jpg
#   ✅ TRAIN IMG_5689.HEIC → shuang_quan_051.jpg
#   ✅ TRAIN IMG_E2348.JPG → shuang_quan_052.jpg
#   ✅ TRAIN IMG_2334.JPG → shuang_quan_053.jpg
#   📊 shuang_quan final split: train=53, test=22
#
# 👤 Processing wee_xuan (16 raw images):
#   🧪 TEST  WhatsApp Image 2026-03-01 at 12.44.29 AM.jpeg → wee_xuan_test_001.jpg
#   🧪 TEST  WhatsApp Image 2026-03-01 at 12.44.30 AM (2).jpeg → wee_xuan_test_002.jpg
#   🧪 TEST  WhatsApp Image 2026-02-24 at 9.44.28 AM.jpeg → wee_xuan_test_003.jpg
#   🧪 TEST  IMG_E8277.HEIC → wee_xuan_test_004.jpg
#   🧪 TEST  IMG_0978.HEIC → wee_xuan_test_005.jpg
#   🎯 Train kept: 11
#   ✅ TRAIN WhatsApp Image 2026-03-01 at 12.44.30 AM.jpeg → wee_xuan_001.jpg
#   ✅ TRAIN WhatsApp Image 2026-03-01 at 12.44.29 AM (1).jpeg → wee_xuan_002.jpg
#   ✅ TRAIN IMG_8277.HEIC → wee_xuan_003.jpg
#   ✅ TRAIN WhatsApp Image 2026-03-01 at 12.44.29 AM (3).jpeg → wee_xuan_004.jpg
#   ✅ TRAIN WhatsApp Image 2026-03-01 at 12.44.30 AM (1).jpeg → wee_xuan_005.jpg
#   ✅ TRAIN IMG_9682.HEIC → wee_xuan_006.jpg
#   ✅ TRAIN WhatsApp Image 2026-03-01 at 12.44.29 AM (2).jpeg → wee_xuan_007.jpg
#   ✅ TRAIN WhatsApp Image 2026-03-01 at 12.44.31 AM (1).jpeg → wee_xuan_008.jpg
#   ✅ TRAIN WhatsApp Image 2026-02-24 at 9.45.43 AM.jpeg → wee_xuan_009.jpg
#   ✅ TRAIN WhatsApp Image 2026-03-01 at 12.44.28 AM.jpeg → wee_xuan_010.jpg
#   ✅ TRAIN WhatsApp Image 2026-03-01 at 12.44.31 AM.jpeg → wee_xuan_011.jpg
#   📊 wee_xuan final split: train=11, test=5
#
# 👤 Processing xiang_yue (14 raw images):
#   🧪 TEST  photo_4_2026-03-13_23-52-45.jpg → xiang_yue_test_001.jpg
#   🧪 TEST  photo_7_2026-03-13_23-52-45.jpg → xiang_yue_test_002.jpg
#   🧪 TEST  photo_8_2026-03-13_23-52-45.jpg → xiang_yue_test_003.jpg
#   🧪 TEST  photo_6_2026-03-13_23-52-45.jpg → xiang_yue_test_004.jpg
#   🎯 Train kept: 10
#   ✅ TRAIN IMG_E1693.JPG → xiang_yue_001.jpg
#   ✅ TRAIN photo_2_2026-03-13_23-52-45.jpg → xiang_yue_002.jpg
#   ✅ TRAIN IMG_1694.JPG → xiang_yue_003.jpg
#   ✅ TRAIN photo_10_2026-03-13_23-52-45.jpg → xiang_yue_004.jpg
#   ✅ TRAIN photo_9_2026-03-13_23-52-45.jpg → xiang_yue_005.jpg
#   ✅ TRAIN photo_1_2026-03-13_23-52-45.jpg → xiang_yue_006.jpg
#   ✅ TRAIN photo_5_2026-03-13_23-52-45.jpg → xiang_yue_007.jpg
#   ✅ TRAIN photo_3_2026-03-13_23-52-45.jpg → xiang_yue_008.jpg
#   ✅ TRAIN IMG_1693.JPG → xiang_yue_009.jpg
#   ✅ TRAIN IMG_E1694.JPG → xiang_yue_010.jpg
#   📊 xiang_yue final split: train=10, test=4
#
# 👤 Processing xu_sheng (23 raw images):
#   🧪 TEST  IMG_8203.HEIC → xu_sheng_test_001.jpg
#   🧪 TEST  IMG_9687.HEIC → xu_sheng_test_002.jpg
#   🧪 TEST  IMG_8213.HEIC → xu_sheng_test_003.jpg
#   🧪 TEST  IMG_9688.HEIC → xu_sheng_test_004.jpg
#   🧪 TEST  IMG_8469.HEIC → xu_sheng_test_005.jpg
#   🧪 TEST  IMG_0697.HEIC → xu_sheng_test_006.jpg
#   🧪 TEST  IMG_2140.JPG → xu_sheng_test_007.jpg
#   🎯 Train kept: 16
#   ✅ TRAIN IMG_0698.HEIC → xu_sheng_001.jpg
#   ✅ TRAIN IMG_1396.HEIC → xu_sheng_002.jpg
#   ✅ TRAIN IMG_0700.HEIC → xu_sheng_003.jpg
#   ✅ TRAIN LVXW5081.JPG → xu_sheng_004.jpg
#   ✅ TRAIN IMG_9686.HEIC → xu_sheng_005.jpg
#   ✅ TRAIN IMG_8204.HEIC → xu_sheng_006.jpg
#   ✅ TRAIN IMG_8119.HEIC → xu_sheng_007.jpg
#   ✅ TRAIN IMG_9684.HEIC → xu_sheng_008.jpg
#   ✅ TRAIN VHII9989.JPG → xu_sheng_009.jpg
#   ✅ TRAIN IMG_0699.HEIC → xu_sheng_010.jpg
#   ✅ TRAIN IMG_0696.HEIC → xu_sheng_011.jpg
#   ✅ TRAIN IMG_9372.JPG → xu_sheng_012.jpg
#   ✅ TRAIN IMG_8237.HEIC → xu_sheng_013.jpg
#   ✅ TRAIN IMG_8312.JPG → xu_sheng_014.jpg
#   ✅ TRAIN IMG_8311.HEIC → xu_sheng_015.jpg
#   ✅ TRAIN IMG_9685.HEIC → xu_sheng_016.jpg
#   📊 xu_sheng final split: train=16, test=7
#
# 👤 Processing yoke_hong (49 raw images):
#   🧪 TEST  IMG_5252.HEIC → yoke_hong_test_001.jpg
#   🧪 TEST  WhatsApp Image 2026-02-24 at 9.45.42 AM.jpeg → yoke_hong_test_002.jpg
#   🧪 TEST  IMG_5239.HEIC → yoke_hong_test_003.jpg
#   🧪 TEST  IMG_5241.HEIC → yoke_hong_test_004.jpg
#   🧪 TEST  IMG_5262.HEIC → yoke_hong_test_005.jpg
#   🧪 TEST  IMG_5260.HEIC → yoke_hong_test_006.jpg
#   🧪 TEST  IMG_5248.HEIC → yoke_hong_test_007.jpg
#   🧪 TEST  IMG_5235.HEIC → yoke_hong_test_008.jpg
#   🧪 TEST  IMG_5240.HEIC → yoke_hong_test_009.jpg
#   🧪 TEST  IMG_5251.HEIC → yoke_hong_test_010.jpg
#   🧪 TEST  IMG_1546.HEIC → yoke_hong_test_011.jpg
#   🧪 TEST  IMG_5237.HEIC → yoke_hong_test_012.jpg
#   🧪 TEST  IMG_5259.HEIC → yoke_hong_test_013.jpg
#   🧪 TEST  IMG_0660.HEIC → yoke_hong_test_014.jpg
#   🧪 TEST  IMG_1542.HEIC → yoke_hong_test_015.jpg
#   🎯 Train kept: 34
#   ✅ TRAIN IMG_5246.HEIC → yoke_hong_001.jpg
#   ✅ TRAIN IMG_5250.HEIC → yoke_hong_002.jpg
#   ✅ TRAIN IMG_5263.HEIC → yoke_hong_003.jpg
#   ✅ TRAIN IMG_0662.HEIC → yoke_hong_004.jpg
#   ✅ TRAIN IMG_0658.HEIC → yoke_hong_005.jpg
#   ✅ TRAIN IMG_5245.HEIC → yoke_hong_006.jpg
#   ✅ TRAIN IMG_0656.HEIC → yoke_hong_007.jpg
#   ✅ TRAIN IMG_0693.HEIC → yoke_hong_008.jpg
#   ✅ TRAIN IMG_5242.HEIC → yoke_hong_009.jpg
#   ✅ TRAIN IMG_5266.HEIC → yoke_hong_010.jpg
#   ✅ TRAIN IMG_5265.HEIC → yoke_hong_011.jpg
#   ✅ TRAIN WhatsApp Image 2026-02-24 at 9.44.54 AM.jpeg → yoke_hong_012.jpg
#   ✅ TRAIN WhatsApp Image 2026-02-24 at 9.45.43 AM.jpeg → yoke_hong_013.jpg
#   ✅ TRAIN IMG_5258.HEIC → yoke_hong_014.jpg
#   ✅ TRAIN IMG_5243.HEIC → yoke_hong_015.jpg
#   ✅ TRAIN IMG_5249.HEIC → yoke_hong_016.jpg
#   ✅ TRAIN IMG_1545.HEIC → yoke_hong_017.jpg
#   ✅ TRAIN IMG_5264.HEIC → yoke_hong_018.jpg
#   ✅ TRAIN IMG_5257.HEIC → yoke_hong_019.jpg
#   ✅ TRAIN IMG_5247.HEIC → yoke_hong_020.jpg
#   ✅ TRAIN IMG_5253.HEIC → yoke_hong_021.jpg
#   ✅ TRAIN IMG_0659.HEIC → yoke_hong_022.jpg
#   ✅ TRAIN IMG_5261.HEIC → yoke_hong_023.jpg
#   ✅ TRAIN IMG_5244.HEIC → yoke_hong_024.jpg
#   ✅ TRAIN IMG_5254.HEIC → yoke_hong_025.jpg
#   ✅ TRAIN IMG_5255.HEIC → yoke_hong_026.jpg
#   ✅ TRAIN IMG_5238.HEIC → yoke_hong_027.jpg
#   ✅ TRAIN IMG_0694.HEIC → yoke_hong_028.jpg
#   ✅ TRAIN IMG_5256.HEIC → yoke_hong_029.jpg
#   ✅ TRAIN IMG_5236.HEIC → yoke_hong_030.jpg
#   ✅ TRAIN IMG_1544.HEIC → yoke_hong_031.jpg
#   ✅ TRAIN IMG_0692.HEIC → yoke_hong_032.jpg
#   ✅ TRAIN IMG_0657.HEIC → yoke_hong_033.jpg
#   ✅ TRAIN IMG_1547.HEIC → yoke_hong_034.jpg
#   📊 yoke_hong final split: train=34, test=15
#
# 👤 Processing yong_kang (13 raw images):
#   🧪 TEST  photo_13_2026-03-09_19-08-19.jpg → yong_kang_test_001.jpg
#   🧪 TEST  photo_12_2026-03-09_19-08-19.jpg → yong_kang_test_002.jpg
#   🧪 TEST  photo_16_2026-03-09_19-08-19.jpg → yong_kang_test_003.jpg
#   🧪 TEST  photo_14_2026-03-09_19-08-19.jpg → yong_kang_test_004.jpg
#   🎯 Train kept: 9
#   ✅ TRAIN photo_11_2026-03-09_19-08-19.jpg → yong_kang_001.jpg
#   ✅ TRAIN WhatsApp Image 2026-02-24 at 9.45.41 AM.jpeg → yong_kang_002.jpg
#   ✅ TRAIN photo_15_2026-03-09_19-08-19.jpg → yong_kang_003.jpg
#   ✅ TRAIN photo_19_2026-03-09_19-08-19.jpg → yong_kang_004.jpg
#   ✅ TRAIN photo_17_2026-03-09_19-08-19.jpg → yong_kang_005.jpg
#   ✅ TRAIN WhatsApp Image 2026-02-24 at 9.44.46 AM.jpeg → yong_kang_006.jpg
#   ✅ TRAIN photo_18_2026-03-09_19-08-19.jpg → yong_kang_007.jpg
#   ✅ TRAIN WhatsApp Image 2026-02-24 at 9.45.42 AM.jpeg → yong_kang_008.jpg
#   ✅ TRAIN photo_10_2026-03-09_19-08-19.jpg → yong_kang_009.jpg
#   📊 yong_kang final split: train=9, test=4
#
# 👤 Processing zi_herng (11 raw images):
#   🧪 TEST  photo_3_2026-03-09_19-08-19.jpg → zi_herng_test_001.jpg
#   🧪 TEST  WhatsApp Image 2026-02-24 at 9.45.44 AM.jpeg → zi_herng_test_002.jpg
#   🧪 TEST  photo_4_2026-03-09_19-08-19.jpg → zi_herng_test_003.jpg
#   🎯 Train kept: 8
#   ✅ TRAIN photo_6_2026-03-09_19-08-19.jpg → zi_herng_001.jpg
#   ✅ TRAIN photo_9_2026-03-09_19-08-19.jpg → zi_herng_002.jpg
#   ✅ TRAIN photo_5_2026-03-09_19-08-19.jpg → zi_herng_003.jpg
#   ✅ TRAIN photo_2_2026-03-09_19-08-19.jpg → zi_herng_004.jpg
#   ✅ TRAIN photo_8_2026-03-09_19-08-19.jpg → zi_herng_005.jpg
#   ✅ TRAIN photo_10_2026-03-09_19-08-05.jpg → zi_herng_006.jpg
#   ✅ TRAIN photo_7_2026-03-09_19-08-19.jpg → zi_herng_007.jpg
#   ✅ TRAIN photo_1_2026-03-09_19-08-19.jpg → zi_herng_008.jpg
#   📊 zi_herng final split: train=8, test=3
#
# ✨ CONVERSION + SPLIT COMPLETE!
#   ✅ Converted train images: 361
#   🏋️ Train raw images:       361
#   🧪 Test raw images:        153
#   ❌ Failed:                 0
#   📁 Converted (train): ..\data\converted
#   📁 Train raw:         ..\data\train_raw
#   📁 Test raw:          ..\data\test_raw

# %% [markdown]
# # Step 2: Grayscale & CLAHE Preprocessing
#
# Apply grayscale conversion and CLAHE enhancement to all converted images for better face detection:

# %%
class ImagePreprocessor:
    def __init__(self, clahe_clip_limit=CLAHE_CLIP_LIMIT, clahe_grid_size=CLAHE_GRID_SIZE):
        """Initialize preprocessor with CLAHE settings"""
        self.clahe = cv2.createCLAHE(clipLimit=clahe_clip_limit, tileGridSize=clahe_grid_size)
        print(f"✅ Image preprocessor initialized")
        print(f"   • CLAHE clip limit: {clahe_clip_limit}")
        print(f"   • CLAHE grid size: {clahe_grid_size}")
    
    def preprocess_image(self, image):
        """Apply CLAHE enhancement on grayscale image"""
        if len(image.shape) == 3:
            gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        else:
            gray = image
        
        enhanced = self.clahe.apply(gray)
        return enhanced
    
    def preprocess_folder(self, input_folder, output_folder):
        """Process all images in a folder and save CLAHE-only outputs"""
        # Verify folders exist
        if not os.path.exists(input_folder):
            print(f"❌ Input folder not found: {input_folder}")
            return 0, 0
        
        if not os.path.exists(output_folder):
            print(f"❌ Output folder not found: {output_folder}")
            return 0, 0
        
        # Get person folders
        person_folders = [f for f in os.listdir(input_folder) 
                         if os.path.isdir(os.path.join(input_folder, f))]
        
        total_processed = 0
        total_failed = 0
        
        for person in person_folders:
            person_input_path = os.path.join(input_folder, person)
            person_output_path = os.path.join(output_folder, person)
            if not os.path.exists(person_output_path):
                os.makedirs(person_output_path, exist_ok=True)

            old_outputs = [f for f in os.listdir(person_output_path)
                           if Path(f).suffix.lower() in {'.jpg', '.jpeg', '.png'}]
            for old_file in old_outputs:
                os.remove(os.path.join(person_output_path, old_file))
            if old_outputs:
                print(f"Cleared {len(old_outputs)} old preprocessed file(s) for {person}")
            
            # Get image files
            image_files = [f for f in os.listdir(person_input_path) if f.lower().endswith('.jpg')]
            
            # Skip folders with no images — don't create empty output dirs
            if not image_files:
                print(f"  ⚠️ No images found for {person} — skipped")
                continue
            
            print(f"\n👤 Preprocessing {person} ({len(image_files)} images):")
            
            for image_file in image_files:
                input_path = os.path.join(person_input_path, image_file)
                image = cv2.imread(input_path)
                
                if image is None:
                    print(f"  ❌ Failed to read: {image_file}")
                    total_failed += 1
                    continue
                
                # Apply preprocessing (CLAHE only)
                enhanced = self.preprocess_image(image)
                
                # Save CLAHE version only
                base_name = Path(image_file).stem
                enhanced_path = os.path.join(person_output_path, f"{base_name}_clahe.jpg")
                cv2.imwrite(enhanced_path, enhanced)
                
                total_processed += 1
                print(f"  ✅ {image_file} → CLAHE version")
        
        print(f"\n✨ PREPROCESSING COMPLETE!")
        print(f"  ✅ Processed: {total_processed}")
        print(f"  ❌ Failed: {total_failed}")
        print(f"  📁 Output: {output_folder}")
        
        return total_processed, total_failed

# Initialize preprocessor
preprocessor = ImagePreprocessor()
print("🔄 Image preprocessor ready!")
# Out:
# ✅ Image preprocessor initialized
#    • CLAHE clip limit: 2.0
#    • CLAHE grid size: (8, 8)
# 🔄 Image preprocessor ready!

# %%
def run_preprocessing():
    """Apply grayscale + CLAHE preprocessing to converted images"""
    print("🔄 STARTING PREPROCESSING")  
    print("=" * 50)
    
    if not os.path.exists(CONVERTED_FOLDER):
        print("❌ Converted folder not found! Please run image conversion first.")
        return
    
    # Run preprocessing
    stats = preprocessor.preprocess_folder(CONVERTED_FOLDER, PREPROCESSED_FOLDER)
    
    print("\n📊 PREPROCESSING SUMMARY:")
    print(f"Images processed: {stats[0]}")
    print(f"Failed: {stats[1]}")
    print(f"📁 Output: {PREPROCESSED_FOLDER}")
    
    return stats

# Run preprocessing
preprocessing_stats = run_preprocessing()
# Out:
# 🔄 STARTING PREPROCESSING
# ==================================================
# Cleared 29 old preprocessed file(s) for benjamin
#
# 👤 Preprocessing benjamin (29 images):
#   ✅ benjamin_001.jpg → CLAHE version
#   ✅ benjamin_002.jpg → CLAHE version
#   ✅ benjamin_003.jpg → CLAHE version
#   ✅ benjamin_004.jpg → CLAHE version
#   ✅ benjamin_005.jpg → CLAHE version
#   ✅ benjamin_006.jpg → CLAHE version
#   ✅ benjamin_007.jpg → CLAHE version
#   ✅ benjamin_008.jpg → CLAHE version
#   ✅ benjamin_009.jpg → CLAHE version
#   ✅ benjamin_010.jpg → CLAHE version
#   ✅ benjamin_011.jpg → CLAHE version
#   ✅ benjamin_012.jpg → CLAHE version
#   ✅ benjamin_013.jpg → CLAHE version
#   ✅ benjamin_014.jpg → CLAHE version
#   ✅ benjamin_015.jpg → CLAHE version
#   ✅ benjamin_016.jpg → CLAHE version
#   ✅ benjamin_017.jpg → CLAHE version
#   ✅ benjamin_018.jpg → CLAHE version
#   ✅ benjamin_019.jpg → CLAHE version
#   ✅ benjamin_020.jpg → CLAHE version
#   ✅ benjamin_021.jpg → CLAHE version
#   ✅ benjamin_022.jpg → CLAHE version
#   ✅ benjamin_023.jpg → CLAHE version
#   ✅ benjamin_024.jpg → CLAHE version
#   ✅ benjamin_025.jpg → CLAHE version
#   ✅ benjamin_026.jpg → CLAHE version
#   ✅ benjamin_027.jpg → CLAHE version
#   ✅ benjamin_028.jpg → CLAHE version
#   ✅ benjamin_029.jpg → CLAHE version
# Cleared 25 old preprocessed file(s) for chern_tak
#
# 👤 Preprocessing chern_tak (25 images):
#   ✅ chern_tak_001.jpg → CLAHE version
#   ✅ chern_tak_002.jpg → CLAHE version
#   ✅ chern_tak_003.jpg → CLAHE version
#   ✅ chern_tak_004.jpg → CLAHE version
#   ✅ chern_tak_005.jpg → CLAHE version
#   ✅ chern_tak_006.jpg → CLAHE version
#   ✅ chern_tak_007.jpg → CLAHE version
#   ✅ chern_tak_008.jpg → CLAHE version
#   ✅ chern_tak_009.jpg → CLAHE version
#   ✅ chern_tak_010.jpg → CLAHE version
#   ✅ chern_tak_011.jpg → CLAHE version
#   ✅ chern_tak_012.jpg → CLAHE version
#   ✅ chern_tak_013.jpg → CLAHE version
#   ✅ chern_tak_014.jpg → CLAHE version
#   ✅ chern_tak_015.jpg → CLAHE version
#   ✅ chern_tak_016.jpg → CLAHE version
#   ✅ chern_tak_017.jpg → CLAHE version
#   ✅ chern_tak_018.jpg → CLAHE version
#   ✅ chern_tak_019.jpg → CLAHE version
#   ✅ chern_tak_020.jpg → CLAHE version
#   ✅ chern_tak_021.jpg → CLAHE version
#   ✅ chern_tak_022.jpg → CLAHE version
#   ✅ chern_tak_023.jpg → CLAHE version
#   ✅ chern_tak_024.jpg → CLAHE version
#   ✅ chern_tak_025.jpg → CLAHE version
# Cleared 10 old preprocessed file(s) for chillien
#
# 👤 Preprocessing chillien (10 images):
#   ✅ chillien_001.jpg → CLAHE version
#   ✅ chillien_002.jpg → CLAHE version
#   ✅ chillien_003.jpg → CLAHE version
#   ✅ chillien_004.jpg → CLAHE version
#   ✅ chillien_005.jpg → CLAHE version
#   ✅ chillien_006.jpg → CLAHE version
#   ✅ chillien_007.jpg → CLAHE version
#   ✅ chillien_008.jpg → CLAHE version
#   ✅ chillien_009.jpg → CLAHE version
#   ✅ chillien_010.jpg → CLAHE version
# Cleared 59 old preprocessed file(s) for daniel
#
# 👤 Preprocessing daniel (59 images):
#   ✅ daniel_001.jpg → CLAHE version
#   ✅ daniel_002.jpg → CLAHE version
#   ✅ daniel_003.jpg → CLAHE version
#   ✅ daniel_004.jpg → CLAHE version
#   ✅ daniel_005.jpg → CLAHE version
#   ✅ daniel_006.jpg → CLAHE version
#   ✅ daniel_007.jpg → CLAHE version
#   ✅ daniel_008.jpg → CLAHE version
#   ✅ daniel_009.jpg → CLAHE version
#   ✅ daniel_010.jpg → CLAHE version
#   ✅ daniel_011.jpg → CLAHE version
#   ✅ daniel_012.jpg → CLAHE version
#   ✅ daniel_013.jpg → CLAHE version
#   ✅ daniel_014.jpg → CLAHE version
#   ✅ daniel_015.jpg → CLAHE version
#   ✅ daniel_016.jpg → CLAHE version
#   ✅ daniel_017.jpg → CLAHE version
#   ✅ daniel_018.jpg → CLAHE version
#   ✅ daniel_019.jpg → CLAHE version
#   ✅ daniel_020.jpg → CLAHE version
#   ✅ daniel_021.jpg → CLAHE version
#   ✅ daniel_022.jpg → CLAHE version
#   ✅ daniel_023.jpg → CLAHE version
#   ✅ daniel_024.jpg → CLAHE version
#   ✅ daniel_025.jpg → CLAHE version
#   ✅ daniel_026.jpg → CLAHE version
#   ✅ daniel_027.jpg → CLAHE version
#   ✅ daniel_028.jpg → CLAHE version
#   ✅ daniel_029.jpg → CLAHE version
#   ✅ daniel_030.jpg → CLAHE version
#   ✅ daniel_031.jpg → CLAHE version
#   ✅ daniel_032.jpg → CLAHE version
#   ✅ daniel_033.jpg → CLAHE version
#   ✅ daniel_034.jpg → CLAHE version
#   ✅ daniel_035.jpg → CLAHE version
#   ✅ daniel_036.jpg → CLAHE version
#   ✅ daniel_037.jpg → CLAHE version
#   ✅ daniel_038.jpg → CLAHE version
#   ✅ daniel_039.jpg → CLAHE version
#   ✅ daniel_040.jpg → CLAHE version
#   ✅ daniel_041.jpg → CLAHE version
#   ✅ daniel_042.jpg → CLAHE version
#   ✅ daniel_043.jpg → CLAHE version
#   ✅ daniel_044.jpg → CLAHE version
#   ✅ daniel_045.jpg → CLAHE version
#   ✅ daniel_046.jpg → CLAHE version
#   ✅ daniel_047.jpg → CLAHE version
#   ✅ daniel_048.jpg → CLAHE version
#   ✅ daniel_049.jpg → CLAHE version
#   ✅ daniel_050.jpg → CLAHE version
#   ✅ daniel_051.jpg → CLAHE version
#   ✅ daniel_052.jpg → CLAHE version
#   ✅ daniel_053.jpg → CLAHE version
#   ✅ daniel_054.jpg → CLAHE version
#   ✅ daniel_055.jpg → CLAHE version
#   ✅ daniel_056.jpg → CLAHE version
#   ✅ daniel_057.jpg → CLAHE version
#   ✅ daniel_058.jpg → CLAHE version
#   ✅ daniel_059.jpg → CLAHE version
# Cleared 8 old preprocessed file(s) for Dr.Nurul
#
# 👤 Preprocessing Dr.Nurul (8 images):
#   ✅ Dr.Nurul_001.jpg → CLAHE version
#   ✅ Dr.Nurul_002.jpg → CLAHE version
#   ✅ Dr.Nurul_003.jpg → CLAHE version
#   ✅ Dr.Nurul_004.jpg → CLAHE version
#   ✅ Dr.Nurul_005.jpg → CLAHE version
#   ✅ Dr.Nurul_006.jpg → CLAHE version
#   ✅ Dr.Nurul_007.jpg → CLAHE version
#   ✅ Dr.Nurul_008.jpg → CLAHE version
# Cleared 28 old preprocessed file(s) for dylan
#
# 👤 Preprocessing dylan (28 images):
#   ✅ dylan_001.jpg → CLAHE version
#   ✅ dylan_002.jpg → CLAHE version
#   ✅ dylan_003.jpg → CLAHE version
#   ✅ dylan_004.jpg → CLAHE version
#   ✅ dylan_005.jpg → CLAHE version
#   ✅ dylan_006.jpg → CLAHE version
#   ✅ dylan_007.jpg → CLAHE version
#   ✅ dylan_008.jpg → CLAHE version
#   ✅ dylan_009.jpg → CLAHE version
#   ✅ dylan_010.jpg → CLAHE version
#   ✅ dylan_011.jpg → CLAHE version
#   ✅ dylan_012.jpg → CLAHE version
#   ✅ dylan_013.jpg → CLAHE version
#   ✅ dylan_014.jpg → CLAHE version
#   ✅ dylan_015.jpg → CLAHE version
#   ✅ dylan_016.jpg → CLAHE version
#   ✅ dylan_017.jpg → CLAHE version
#   ✅ dylan_018.jpg → CLAHE version
#   ✅ dylan_019.jpg → CLAHE version
#   ✅ dylan_020.jpg → CLAHE version
#   ✅ dylan_021.jpg → CLAHE version
#   ✅ dylan_022.jpg → CLAHE version
#   ✅ dylan_023.jpg → CLAHE version
#   ✅ dylan_024.jpg → CLAHE version
#   ✅ dylan_025.jpg → CLAHE version
#   ✅ dylan_026.jpg → CLAHE version
#   ✅ dylan_027.jpg → CLAHE version
#   ✅ dylan_028.jpg → CLAHE version
# Cleared 8 old preprocessed file(s) for han_soon
#
# 👤 Preprocessing han_soon (8 images):
#   ✅ han_soon_001.jpg → CLAHE version
#   ✅ han_soon_002.jpg → CLAHE version
#   ✅ han_soon_003.jpg → CLAHE version
#   ✅ han_soon_004.jpg → CLAHE version
#   ✅ han_soon_005.jpg → CLAHE version
#   ✅ han_soon_006.jpg → CLAHE version
#   ✅ han_soon_007.jpg → CLAHE version
#   ✅ han_soon_008.jpg → CLAHE version
# Cleared 7 old preprocessed file(s) for harry
#
# 👤 Preprocessing harry (7 images):
#   ✅ harry_001.jpg → CLAHE version
#   ✅ harry_002.jpg → CLAHE version
#   ✅ harry_003.jpg → CLAHE version
#   ✅ harry_004.jpg → CLAHE version
#   ✅ harry_005.jpg → CLAHE version
#   ✅ harry_006.jpg → CLAHE version
#   ✅ harry_007.jpg → CLAHE version
# Cleared 7 old preprocessed file(s) for isaac
#
# 👤 Preprocessing isaac (7 images):
#   ✅ isaac_001.jpg → CLAHE version
#   ✅ isaac_002.jpg → CLAHE version
#   ✅ isaac_003.jpg → CLAHE version
#   ✅ isaac_004.jpg → CLAHE version
#   ✅ isaac_005.jpg → CLAHE version
#   ✅ isaac_006.jpg → CLAHE version
#   ✅ isaac_007.jpg → CLAHE version
# Cleared 6 old preprocessed file(s) for jing_ang
#
# 👤 Preprocessing jing_ang (6 images):
#   ✅ jing_ang_001.jpg → CLAHE version
#   ✅ jing_ang_002.jpg → CLAHE version
#   ✅ jing_ang_003.jpg → CLAHE version
#   ✅ jing_ang_004.jpg → CLAHE version
#   ✅ jing_ang_005.jpg → CLAHE version
#   ✅ jing_ang_006.jpg → CLAHE version
# Cleared 6 old preprocessed file(s) for jun_wei
#
# 👤 Preprocessing jun_wei (6 images):
#   ✅ jun_wei_001.jpg → CLAHE version
#   ✅ jun_wei_002.jpg → CLAHE version
#   ✅ jun_wei_003.jpg → CLAHE version
#   ✅ jun_wei_004.jpg → CLAHE version
#   ✅ jun_wei_005.jpg → CLAHE version
#   ✅ jun_wei_006.jpg → CLAHE version
# Cleared 11 old preprocessed file(s) for kang_kai
#
# 👤 Preprocessing kang_kai (11 images):
#   ✅ kang_kai_001.jpg → CLAHE version
#   ✅ kang_kai_002.jpg → CLAHE version
#   ✅ kang_kai_003.jpg → CLAHE version
#   ✅ kang_kai_004.jpg → CLAHE version
#   ✅ kang_kai_005.jpg → CLAHE version
#   ✅ kang_kai_006.jpg → CLAHE version
#   ✅ kang_kai_007.jpg → CLAHE version
#   ✅ kang_kai_008.jpg → CLAHE version
#   ✅ kang_kai_009.jpg → CLAHE version
#   ✅ kang_kai_010.jpg → CLAHE version
#   ✅ kang_kai_011.jpg → CLAHE version
# Cleared 8 old preprocessed file(s) for marion
#
# 👤 Preprocessing marion (8 images):
#   ✅ marion_001.jpg → CLAHE version
#   ✅ marion_002.jpg → CLAHE version
#   ✅ marion_003.jpg → CLAHE version
#   ✅ marion_004.jpg → CLAHE version
#   ✅ marion_005.jpg → CLAHE version
#   ✅ marion_006.jpg → CLAHE version
#   ✅ marion_007.jpg → CLAHE version
#   ✅ marion_008.jpg → CLAHE version
# Cleared 8 old preprocessed file(s) for qi_xuan
#
# 👤 Preprocessing qi_xuan (8 images):
#   ✅ qi_xuan_001.jpg → CLAHE version
#   ✅ qi_xuan_002.jpg → CLAHE version
#   ✅ qi_xuan_003.jpg → CLAHE version
#   ✅ qi_xuan_004.jpg → CLAHE version
#   ✅ qi_xuan_005.jpg → CLAHE version
#   ✅ qi_xuan_006.jpg → CLAHE version
#   ✅ qi_xuan_007.jpg → CLAHE version
#   ✅ qi_xuan_008.jpg → CLAHE version
# Cleared 53 old preprocessed file(s) for shuang_quan
#
# 👤 Preprocessing shuang_quan (53 images):
#   ✅ shuang_quan_001.jpg → CLAHE version
#   ✅ shuang_quan_002.jpg → CLAHE version
#   ✅ shuang_quan_003.jpg → CLAHE version
#   ✅ shuang_quan_004.jpg → CLAHE version
#   ✅ shuang_quan_005.jpg → CLAHE version
#   ✅ shuang_quan_006.jpg → CLAHE version
#   ✅ shuang_quan_007.jpg → CLAHE version
#   ✅ shuang_quan_008.jpg → CLAHE version
#   ✅ shuang_quan_009.jpg → CLAHE version
#   ✅ shuang_quan_010.jpg → CLAHE version
#   ✅ shuang_quan_011.jpg → CLAHE version
#   ✅ shuang_quan_012.jpg → CLAHE version
#   ✅ shuang_quan_013.jpg → CLAHE version
#   ✅ shuang_quan_014.jpg → CLAHE version
#   ✅ shuang_quan_015.jpg → CLAHE version
#   ✅ shuang_quan_016.jpg → CLAHE version
#   ✅ shuang_quan_017.jpg → CLAHE version
#   ✅ shuang_quan_018.jpg → CLAHE version
#   ✅ shuang_quan_019.jpg → CLAHE version
#   ✅ shuang_quan_020.jpg → CLAHE version
#   ✅ shuang_quan_021.jpg → CLAHE version
#   ✅ shuang_quan_022.jpg → CLAHE version
#   ✅ shuang_quan_023.jpg → CLAHE version
#   ✅ shuang_quan_024.jpg → CLAHE version
#   ✅ shuang_quan_025.jpg → CLAHE version
#   ✅ shuang_quan_026.jpg → CLAHE version
#   ✅ shuang_quan_027.jpg → CLAHE version
#   ✅ shuang_quan_028.jpg → CLAHE version
#   ✅ shuang_quan_029.jpg → CLAHE version
#   ✅ shuang_quan_030.jpg → CLAHE version
#   ✅ shuang_quan_031.jpg → CLAHE version
#   ✅ shuang_quan_032.jpg → CLAHE version
#   ✅ shuang_quan_033.jpg → CLAHE version
#   ✅ shuang_quan_034.jpg → CLAHE version
#   ✅ shuang_quan_035.jpg → CLAHE version
#   ✅ shuang_quan_036.jpg → CLAHE version
#   ✅ shuang_quan_037.jpg → CLAHE version
#   ✅ shuang_quan_038.jpg → CLAHE version
#   ✅ shuang_quan_039.jpg → CLAHE version
#   ✅ shuang_quan_040.jpg → CLAHE version
#   ✅ shuang_quan_041.jpg → CLAHE version
#   ✅ shuang_quan_042.jpg → CLAHE version
#   ✅ shuang_quan_043.jpg → CLAHE version
#   ✅ shuang_quan_044.jpg → CLAHE version
#   ✅ shuang_quan_045.jpg → CLAHE version
#   ✅ shuang_quan_046.jpg → CLAHE version
#   ✅ shuang_quan_047.jpg → CLAHE version
#   ✅ shuang_quan_048.jpg → CLAHE version
#   ✅ shuang_quan_049.jpg → CLAHE version
#   ✅ shuang_quan_050.jpg → CLAHE version
#   ✅ shuang_quan_051.jpg → CLAHE version
#   ✅ shuang_quan_052.jpg → CLAHE version
#   ✅ shuang_quan_053.jpg → CLAHE version
# Cleared 11 old preprocessed file(s) for wee_xuan
#
# 👤 Preprocessing wee_xuan (11 images):
#   ✅ wee_xuan_001.jpg → CLAHE version
#   ✅ wee_xuan_002.jpg → CLAHE version
#   ✅ wee_xuan_003.jpg → CLAHE version
#   ✅ wee_xuan_004.jpg → CLAHE version
#   ✅ wee_xuan_005.jpg → CLAHE version
#   ✅ wee_xuan_006.jpg → CLAHE version
#   ✅ wee_xuan_007.jpg → CLAHE version
#   ✅ wee_xuan_008.jpg → CLAHE version
#   ✅ wee_xuan_009.jpg → CLAHE version
#   ✅ wee_xuan_010.jpg → CLAHE version
#   ✅ wee_xuan_011.jpg → CLAHE version
# Cleared 10 old preprocessed file(s) for xiang_yue
#
# 👤 Preprocessing xiang_yue (10 images):
#   ✅ xiang_yue_001.jpg → CLAHE version
#   ✅ xiang_yue_002.jpg → CLAHE version
#   ✅ xiang_yue_003.jpg → CLAHE version
#   ✅ xiang_yue_004.jpg → CLAHE version
#   ✅ xiang_yue_005.jpg → CLAHE version
#   ✅ xiang_yue_006.jpg → CLAHE version
#   ✅ xiang_yue_007.jpg → CLAHE version
#   ✅ xiang_yue_008.jpg → CLAHE version
#   ✅ xiang_yue_009.jpg → CLAHE version
#   ✅ xiang_yue_010.jpg → CLAHE version
# Cleared 16 old preprocessed file(s) for xu_sheng
#
# 👤 Preprocessing xu_sheng (16 images):
#   ✅ xu_sheng_001.jpg → CLAHE version
#   ✅ xu_sheng_002.jpg → CLAHE version
#   ✅ xu_sheng_003.jpg → CLAHE version
#   ✅ xu_sheng_004.jpg → CLAHE version
#   ✅ xu_sheng_005.jpg → CLAHE version
#   ✅ xu_sheng_006.jpg → CLAHE version
#   ✅ xu_sheng_007.jpg → CLAHE version
#   ✅ xu_sheng_008.jpg → CLAHE version
#   ✅ xu_sheng_009.jpg → CLAHE version
#   ✅ xu_sheng_010.jpg → CLAHE version
#   ✅ xu_sheng_011.jpg → CLAHE version
#   ✅ xu_sheng_012.jpg → CLAHE version
#   ✅ xu_sheng_013.jpg → CLAHE version
#   ✅ xu_sheng_014.jpg → CLAHE version
#   ✅ xu_sheng_015.jpg → CLAHE version
#   ✅ xu_sheng_016.jpg → CLAHE version
# Cleared 34 old preprocessed file(s) for yoke_hong
#
# 👤 Preprocessing yoke_hong (34 images):
#   ✅ yoke_hong_001.jpg → CLAHE version
#   ✅ yoke_hong_002.jpg → CLAHE version
#   ✅ yoke_hong_003.jpg → CLAHE version
#   ✅ yoke_hong_004.jpg → CLAHE version
#   ✅ yoke_hong_005.jpg → CLAHE version
#   ✅ yoke_hong_006.jpg → CLAHE version
#   ✅ yoke_hong_007.jpg → CLAHE version
#   ✅ yoke_hong_008.jpg → CLAHE version
#   ✅ yoke_hong_009.jpg → CLAHE version
#   ✅ yoke_hong_010.jpg → CLAHE version
#   ✅ yoke_hong_011.jpg → CLAHE version
#   ✅ yoke_hong_012.jpg → CLAHE version
#   ✅ yoke_hong_013.jpg → CLAHE version
#   ✅ yoke_hong_014.jpg → CLAHE version
#   ✅ yoke_hong_015.jpg → CLAHE version
#   ✅ yoke_hong_016.jpg → CLAHE version
#   ✅ yoke_hong_017.jpg → CLAHE version
#   ✅ yoke_hong_018.jpg → CLAHE version
#   ✅ yoke_hong_019.jpg → CLAHE version
#   ✅ yoke_hong_020.jpg → CLAHE version
#   ✅ yoke_hong_021.jpg → CLAHE version
#   ✅ yoke_hong_022.jpg → CLAHE version
#   ✅ yoke_hong_023.jpg → CLAHE version
#   ✅ yoke_hong_024.jpg → CLAHE version
#   ✅ yoke_hong_025.jpg → CLAHE version
#   ✅ yoke_hong_026.jpg → CLAHE version
#   ✅ yoke_hong_027.jpg → CLAHE version
#   ✅ yoke_hong_028.jpg → CLAHE version
#   ✅ yoke_hong_029.jpg → CLAHE version
#   ✅ yoke_hong_030.jpg → CLAHE version
#   ✅ yoke_hong_031.jpg → CLAHE version
#   ✅ yoke_hong_032.jpg → CLAHE version
#   ✅ yoke_hong_033.jpg → CLAHE version
#   ✅ yoke_hong_034.jpg → CLAHE version
# Cleared 9 old preprocessed file(s) for yong_kang
#
# 👤 Preprocessing yong_kang (9 images):
#   ✅ yong_kang_001.jpg → CLAHE version
#   ✅ yong_kang_002.jpg → CLAHE version
#   ✅ yong_kang_003.jpg → CLAHE version
#   ✅ yong_kang_004.jpg → CLAHE version
#   ✅ yong_kang_005.jpg → CLAHE version
#   ✅ yong_kang_006.jpg → CLAHE version
#   ✅ yong_kang_007.jpg → CLAHE version
#   ✅ yong_kang_008.jpg → CLAHE version
#   ✅ yong_kang_009.jpg → CLAHE version
# Cleared 8 old preprocessed file(s) for zi_herng
#
# 👤 Preprocessing zi_herng (8 images):
#   ✅ zi_herng_001.jpg → CLAHE version
#   ✅ zi_herng_002.jpg → CLAHE version
#   ✅ zi_herng_003.jpg → CLAHE version
#   ✅ zi_herng_004.jpg → CLAHE version
#   ✅ zi_herng_005.jpg → CLAHE version
#   ✅ zi_herng_006.jpg → CLAHE version
#   ✅ zi_herng_007.jpg → CLAHE version
#   ✅ zi_herng_008.jpg → CLAHE version
#
# ✨ PREPROCESSING COMPLETE!
#   ✅ Processed: 361
#   ❌ Failed: 0
#   📁 Output: ..\data\preprocessed
#
# 📊 PREPROCESSING SUMMARY:
# Images processed: 361
# Failed: 0
# 📁 Output: ..\data\preprocessed

# %% [markdown]
# # Step 3: Face Detection & ROI Extraction
#
# Detect faces in preprocessed images and extract regions of interest with padding:

# %%
class FaceROIExtractor:
    def __init__(self, padding_ratio=FACE_PADDING_RATIO, target_size=OUTPUT_SIZE):
        """Initialize face ROI extractor for preprocessed images"""
        self.padding_ratio = padding_ratio
        self.target_size = target_size
        
        # Kept for compatibility/diagnostics, but face extraction path uses dlib HOG.
        self.face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
        
        print(f"✅ Face ROI extractor initialized")
        print(f"   • Padding ratio: {padding_ratio}")
        print(f"   • Target output size: {target_size}")
    
    def detect_faces_opencv(self, image):
        """Detect faces using OpenCV cascade classifier"""
        faces = self.face_cascade.detectMultiScale(
            image,
            scaleFactor=1.1,
            minNeighbors=5,
            minSize=(30, 30)
        )
        return [(x, y, w, h) for (x, y, w, h) in faces]
    
    def detect_faces_dlib(self, image):
        """Detect faces using face_recognition library (dlib HOG only)"""
        try:
            # face_recognition expects RGB format
            if len(image.shape) == 3:
                rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            else:
                rgb_image = cv2.cvtColor(image, cv2.COLOR_GRAY2RGB)
            
            # Get face locations
            face_locations = face_recognition.face_locations(rgb_image, model="hog")
            
            # Convert to (x, y, w, h) format
            faces = []
            for (top, right, bottom, left) in face_locations:
                x, y, w, h = left, top, right - left, bottom - top
                faces.append((x, y, w, h))
            
            return faces
        except Exception as e:
            print(f"  ⚠️ dlib HOG detection failed: {e}")
            return []
    
    def extract_roi_with_padding(self, image, x, y, w, h):
        """Extract face ROI with padding"""
        # Calculate padding
        pad_w = int(w * self.padding_ratio)
        pad_h = int(h * self.padding_ratio)
        
        # Calculate padded coordinates
        x1 = max(0, x - pad_w)
        y1 = max(0, y - pad_h)
        x2 = min(image.shape[1], x + w + pad_w)
        y2 = min(image.shape[0], y + h + pad_h)
        
        # Extract ROI
        roi = image[y1:y2, x1:x2]
        
        return roi, (x1, y1, x2, y2)
    
    def process_preprocessed_folder(self, input_folder, output_folder):
        """Process preprocessed images and extract face ROIs"""
        # Verify folders exist
        if not os.path.exists(input_folder):
            print(f"❌ Input folder not found: {input_folder}")
            return 0, 0, 0
        
        if not os.path.exists(output_folder):
            print(f"❌ Output folder not found: {output_folder}")
            print("   Run 'Create Dataset Folders' cell first!")
            return 0, 0, 0
        
        # Get person folders  
        person_folders = [f for f in os.listdir(input_folder) 
                         if os.path.isdir(os.path.join(input_folder, f))]
        
        total_processed = 0
        total_faces = 0
        total_failed = 0
        
        for person in person_folders:
            person_input_path = os.path.join(input_folder, person)
            person_output_path = os.path.join(output_folder, person)
            if not os.path.exists(person_output_path):
                os.makedirs(person_output_path, exist_ok=True)

            old_outputs = [f for f in os.listdir(person_output_path)
                           if Path(f).suffix.lower() in {'.jpg', '.jpeg', '.png'}]
            for old_file in old_outputs:
                os.remove(os.path.join(person_output_path, old_file))
            if old_outputs:
                print(f"  ♻️ Cleared {len(old_outputs)} old face ROI file(s) for {person}")
            
            # Get preprocessed images (CLAHE-only)
            image_files = [f for f in os.listdir(person_input_path) 
                          if f.lower().endswith('_clahe.jpg')]
            
            # Skip folders with no valid images — don't create empty output dirs
            if not image_files:
                print(f"  ⚠️ No preprocessed images found for {person} — skipped")
                continue
            
            print(f"\n👤 Processing {person} ({len(image_files)} preprocessed images):")
            
            for image_file in image_files:
                input_path = os.path.join(person_input_path, image_file)
                image = cv2.imread(input_path)
                
                if image is None:
                    print(f"  ❌ Failed to read: {image_file}")
                    total_failed += 1
                    continue
                
                # Convert to grayscale for face detection if needed
                if len(image.shape) == 3:
                    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
                else:
                    gray = image
                
                # Detect faces
                faces = self.detect_faces_dlib(gray)
                
                if not faces:
                    print(f"  ❌ No face detected: {image_file}")
                    total_failed += 1
                    continue
                
                # Process each detected face
                base_name = Path(image_file).stem
                for i, (x, y, w, h) in enumerate(faces):
                    # Extract ROI with padding
                    roi, coords = self.extract_roi_with_padding(gray, x, y, w, h)
                    
                    # Resize to target size
                    resized_roi = cv2.resize(roi, self.target_size)
                    
                    # Save face ROI
                    face_filename = f"{base_name}_face_{i}.jpg"
                    face_path = os.path.join(person_output_path, face_filename)
                    cv2.imwrite(face_path, resized_roi, [cv2.IMWRITE_JPEG_QUALITY, IMAGE_QUALITY])
                    
                    total_faces += 1
                    print(f"  ✅ {image_file} → face_{i} ({self.target_size}px)")
                
                total_processed += 1
        
        print(f"\n✨ FACE ROI EXTRACTION COMPLETE!")
        print(f"  ✅ Images processed: {total_processed}")
        print(f"  👤 Faces extracted: {total_faces}")
        print(f"  ❌ Failed: {total_failed}")
        print(f"  📁 Output: {output_folder}")
        
        return total_processed, total_faces, total_failed

# Initialize face ROI extractor
roi_extractor = FaceROIExtractor()
print("👁️ Face ROI extractor ready!")
# Out:
# ✅ Face ROI extractor initialized
#    • Padding ratio: 0.2
#    • Target output size: (128, 128)
# 👁️ Face ROI extractor ready!

# %%
def extract_faces_from_preprocessed():
    """Extract face ROIs from preprocessed images"""
    print("👁️ STARTING FACE ROI EXTRACTION")
    print("=" * 50)
    
    if not os.path.exists(PREPROCESSED_FOLDER):
        print("❌ Preprocessed folder not found! Please run preprocessing first.")
        return
    
    # Extract faces from preprocessed images
    stats = roi_extractor.process_preprocessed_folder(PREPROCESSED_FOLDER, FACES_DETECTED_FOLDER)
    
    print("\n📊 EXTRACTION SUMMARY:")
    print(f"Images processed: {stats[0]}")
    print(f"Faces extracted: {stats[1]}")
    print(f"Failed: {stats[2]}")
    
    return stats

# Run face ROI extraction
face_roi_stats = extract_faces_from_preprocessed()
# Out:
# 👁️ STARTING FACE ROI EXTRACTION
# ==================================================
#   ♻️ Cleared 13 old face ROI file(s) for benjamin
#
# 👤 Processing benjamin (29 preprocessed images):
#   ✅ benjamin_001_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: benjamin_002_clahe.jpg
#   ❌ No face detected: benjamin_003_clahe.jpg
#   ❌ No face detected: benjamin_004_clahe.jpg
#   ✅ benjamin_005_clahe.jpg → face_0 ((128, 128)px)
#   ✅ benjamin_006_clahe.jpg → face_0 ((128, 128)px)
#   ✅ benjamin_007_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: benjamin_008_clahe.jpg
#   ❌ No face detected: benjamin_009_clahe.jpg
#   ❌ No face detected: benjamin_010_clahe.jpg
#   ❌ No face detected: benjamin_011_clahe.jpg
#   ❌ No face detected: benjamin_012_clahe.jpg
#   ✅ benjamin_013_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: benjamin_014_clahe.jpg
#   ✅ benjamin_015_clahe.jpg → face_0 ((128, 128)px)
#   ✅ benjamin_016_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: benjamin_017_clahe.jpg
#   ✅ benjamin_018_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: benjamin_019_clahe.jpg
#   ❌ No face detected: benjamin_020_clahe.jpg
#   ✅ benjamin_021_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: benjamin_022_clahe.jpg
#   ❌ No face detected: benjamin_023_clahe.jpg
#   ✅ benjamin_024_clahe.jpg → face_0 ((128, 128)px)
#   ✅ benjamin_025_clahe.jpg → face_0 ((128, 128)px)
#   ✅ benjamin_026_clahe.jpg → face_0 ((128, 128)px)
#   ✅ benjamin_027_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: benjamin_028_clahe.jpg
#   ❌ No face detected: benjamin_029_clahe.jpg
#   ♻️ Cleared 11 old face ROI file(s) for chern_tak
#
# 👤 Processing chern_tak (25 preprocessed images):
#   ❌ No face detected: chern_tak_001_clahe.jpg
#   ✅ chern_tak_002_clahe.jpg → face_0 ((128, 128)px)
#   ✅ chern_tak_003_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: chern_tak_004_clahe.jpg
#   ❌ No face detected: chern_tak_005_clahe.jpg
#   ✅ chern_tak_006_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: chern_tak_007_clahe.jpg
#   ✅ chern_tak_008_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: chern_tak_009_clahe.jpg
#   ❌ No face detected: chern_tak_010_clahe.jpg
#   ❌ No face detected: chern_tak_011_clahe.jpg
#   ❌ No face detected: chern_tak_012_clahe.jpg
#   ✅ chern_tak_013_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: chern_tak_014_clahe.jpg
#   ❌ No face detected: chern_tak_015_clahe.jpg
#   ❌ No face detected: chern_tak_016_clahe.jpg
#   ❌ No face detected: chern_tak_017_clahe.jpg
#   ❌ No face detected: chern_tak_018_clahe.jpg
#   ❌ No face detected: chern_tak_019_clahe.jpg
#   ✅ chern_tak_020_clahe.jpg → face_0 ((128, 128)px)
#   ✅ chern_tak_021_clahe.jpg → face_0 ((128, 128)px)
#   ✅ chern_tak_022_clahe.jpg → face_0 ((128, 128)px)
#   ✅ chern_tak_022_clahe.jpg → face_1 ((128, 128)px)
#   ✅ chern_tak_023_clahe.jpg → face_0 ((128, 128)px)
#   ✅ chern_tak_024_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: chern_tak_025_clahe.jpg
#   ♻️ Cleared 9 old face ROI file(s) for chillien
#
# 👤 Processing chillien (10 preprocessed images):
#   ✅ chillien_001_clahe.jpg → face_0 ((128, 128)px)
#   ✅ chillien_002_clahe.jpg → face_0 ((128, 128)px)
#   ✅ chillien_003_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: chillien_004_clahe.jpg
#   ✅ chillien_005_clahe.jpg → face_0 ((128, 128)px)
#   ✅ chillien_006_clahe.jpg → face_0 ((128, 128)px)
#   ✅ chillien_007_clahe.jpg → face_0 ((128, 128)px)
#   ✅ chillien_008_clahe.jpg → face_0 ((128, 128)px)
#   ✅ chillien_009_clahe.jpg → face_0 ((128, 128)px)
#   ✅ chillien_010_clahe.jpg → face_0 ((128, 128)px)
#   ♻️ Cleared 38 old face ROI file(s) for daniel
#
# 👤 Processing daniel (59 preprocessed images):
#   ✅ daniel_001_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: daniel_002_clahe.jpg
#   ✅ daniel_003_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: daniel_004_clahe.jpg
#   ✅ daniel_005_clahe.jpg → face_0 ((128, 128)px)
#   ✅ daniel_006_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: daniel_007_clahe.jpg
#   ❌ No face detected: daniel_008_clahe.jpg
#   ✅ daniel_009_clahe.jpg → face_0 ((128, 128)px)
#   ✅ daniel_010_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: daniel_011_clahe.jpg
#   ✅ daniel_012_clahe.jpg → face_0 ((128, 128)px)
#   ✅ daniel_013_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: daniel_014_clahe.jpg
#   ❌ No face detected: daniel_015_clahe.jpg
#   ✅ daniel_016_clahe.jpg → face_0 ((128, 128)px)
#   ✅ daniel_017_clahe.jpg → face_0 ((128, 128)px)
#   ✅ daniel_018_clahe.jpg → face_0 ((128, 128)px)
#   ✅ daniel_019_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: daniel_020_clahe.jpg
#   ❌ No face detected: daniel_021_clahe.jpg
#   ❌ No face detected: daniel_022_clahe.jpg
#   ❌ No face detected: daniel_023_clahe.jpg
#   ✅ daniel_024_clahe.jpg → face_0 ((128, 128)px)
#   ✅ daniel_025_clahe.jpg → face_0 ((128, 128)px)
#   ✅ daniel_026_clahe.jpg → face_0 ((128, 128)px)
#   ✅ daniel_027_clahe.jpg → face_0 ((128, 128)px)
#   ✅ daniel_028_clahe.jpg → face_0 ((128, 128)px)
#   ✅ daniel_028_clahe.jpg → face_1 ((128, 128)px)
#   ❌ No face detected: daniel_029_clahe.jpg
#   ✅ daniel_030_clahe.jpg → face_0 ((128, 128)px)
#   ✅ daniel_031_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: daniel_032_clahe.jpg
#   ❌ No face detected: daniel_033_clahe.jpg
#   ✅ daniel_034_clahe.jpg → face_0 ((128, 128)px)
#   ✅ daniel_035_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: daniel_036_clahe.jpg
#   ❌ No face detected: daniel_037_clahe.jpg
#   ✅ daniel_038_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: daniel_039_clahe.jpg
#   ❌ No face detected: daniel_040_clahe.jpg
#   ✅ daniel_041_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: daniel_042_clahe.jpg
#   ✅ daniel_043_clahe.jpg → face_0 ((128, 128)px)
#   ✅ daniel_044_clahe.jpg → face_0 ((128, 128)px)
#   ✅ daniel_044_clahe.jpg → face_1 ((128, 128)px)
#   ✅ daniel_045_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: daniel_046_clahe.jpg
#   ✅ daniel_047_clahe.jpg → face_0 ((128, 128)px)
#   ✅ daniel_048_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: daniel_049_clahe.jpg
#   ❌ No face detected: daniel_050_clahe.jpg
#   ✅ daniel_051_clahe.jpg → face_0 ((128, 128)px)
#   ✅ daniel_052_clahe.jpg → face_0 ((128, 128)px)
#   ✅ daniel_052_clahe.jpg → face_1 ((128, 128)px)
#   ❌ No face detected: daniel_053_clahe.jpg
#   ✅ daniel_054_clahe.jpg → face_0 ((128, 128)px)
#   ✅ daniel_055_clahe.jpg → face_0 ((128, 128)px)
#   ✅ daniel_056_clahe.jpg → face_0 ((128, 128)px)
#   ✅ daniel_057_clahe.jpg → face_0 ((128, 128)px)
#   ✅ daniel_058_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: daniel_059_clahe.jpg
#   ♻️ Cleared 8 old face ROI file(s) for Dr.Nurul
#
# 👤 Processing Dr.Nurul (8 preprocessed images):
#   ✅ Dr.Nurul_001_clahe.jpg → face_0 ((128, 128)px)
#   ✅ Dr.Nurul_002_clahe.jpg → face_0 ((128, 128)px)
#   ✅ Dr.Nurul_003_clahe.jpg → face_0 ((128, 128)px)
#   ✅ Dr.Nurul_004_clahe.jpg → face_0 ((128, 128)px)
#   ✅ Dr.Nurul_005_clahe.jpg → face_0 ((128, 128)px)
#   ✅ Dr.Nurul_006_clahe.jpg → face_0 ((128, 128)px)
#   ✅ Dr.Nurul_007_clahe.jpg → face_0 ((128, 128)px)
#   ✅ Dr.Nurul_008_clahe.jpg → face_0 ((128, 128)px)
#   ♻️ Cleared 23 old face ROI file(s) for dylan
#
# 👤 Processing dylan (28 preprocessed images):
#   ✅ dylan_001_clahe.jpg → face_0 ((128, 128)px)
#   ✅ dylan_002_clahe.jpg → face_0 ((128, 128)px)
#   ✅ dylan_003_clahe.jpg → face_0 ((128, 128)px)
#   ✅ dylan_004_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: dylan_005_clahe.jpg
#   ✅ dylan_006_clahe.jpg → face_0 ((128, 128)px)
#   ✅ dylan_007_clahe.jpg → face_0 ((128, 128)px)
#   ✅ dylan_008_clahe.jpg → face_0 ((128, 128)px)
#   ✅ dylan_009_clahe.jpg → face_0 ((128, 128)px)
#   ✅ dylan_010_clahe.jpg → face_0 ((128, 128)px)
#   ✅ dylan_011_clahe.jpg → face_0 ((128, 128)px)
#   ✅ dylan_012_clahe.jpg → face_0 ((128, 128)px)
#   ✅ dylan_013_clahe.jpg → face_0 ((128, 128)px)
#   ✅ dylan_014_clahe.jpg → face_0 ((128, 128)px)
#   ✅ dylan_015_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: dylan_016_clahe.jpg
#   ✅ dylan_017_clahe.jpg → face_0 ((128, 128)px)
#   ✅ dylan_018_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: dylan_019_clahe.jpg
#   ❌ No face detected: dylan_020_clahe.jpg
#   ✅ dylan_021_clahe.jpg → face_0 ((128, 128)px)
#   ✅ dylan_022_clahe.jpg → face_0 ((128, 128)px)
#   ✅ dylan_023_clahe.jpg → face_0 ((128, 128)px)
#   ✅ dylan_024_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: dylan_025_clahe.jpg
#   ✅ dylan_026_clahe.jpg → face_0 ((128, 128)px)
#   ✅ dylan_027_clahe.jpg → face_0 ((128, 128)px)
#   ✅ dylan_028_clahe.jpg → face_0 ((128, 128)px)
#   ♻️ Cleared 8 old face ROI file(s) for han_soon
#
# 👤 Processing han_soon (8 preprocessed images):
#   ✅ han_soon_001_clahe.jpg → face_0 ((128, 128)px)
#   ✅ han_soon_002_clahe.jpg → face_0 ((128, 128)px)
#   ✅ han_soon_003_clahe.jpg → face_0 ((128, 128)px)
#   ✅ han_soon_004_clahe.jpg → face_0 ((128, 128)px)
#   ✅ han_soon_005_clahe.jpg → face_0 ((128, 128)px)
#   ✅ han_soon_006_clahe.jpg → face_0 ((128, 128)px)
#   ✅ han_soon_007_clahe.jpg → face_0 ((128, 128)px)
#   ✅ han_soon_008_clahe.jpg → face_0 ((128, 128)px)
#   ♻️ Cleared 7 old face ROI file(s) for harry
#
# 👤 Processing harry (7 preprocessed images):
#   ✅ harry_001_clahe.jpg → face_0 ((128, 128)px)
#   ✅ harry_002_clahe.jpg → face_0 ((128, 128)px)
#   ✅ harry_003_clahe.jpg → face_0 ((128, 128)px)
#   ✅ harry_004_clahe.jpg → face_0 ((128, 128)px)
#   ✅ harry_005_clahe.jpg → face_0 ((128, 128)px)
#   ✅ harry_006_clahe.jpg → face_0 ((128, 128)px)
#   ✅ harry_007_clahe.jpg → face_0 ((128, 128)px)
#   ♻️ Cleared 1 old face ROI file(s) for isaac
#
# 👤 Processing isaac (7 preprocessed images):
#   ❌ No face detected: isaac_001_clahe.jpg
#   ❌ No face detected: isaac_002_clahe.jpg
#   ❌ No face detected: isaac_003_clahe.jpg
#   ❌ No face detected: isaac_004_clahe.jpg
#   ❌ No face detected: isaac_005_clahe.jpg
#   ✅ isaac_006_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: isaac_007_clahe.jpg
#   ♻️ Cleared 6 old face ROI file(s) for jing_ang
#
# 👤 Processing jing_ang (6 preprocessed images):
#   ✅ jing_ang_001_clahe.jpg → face_0 ((128, 128)px)
#   ✅ jing_ang_002_clahe.jpg → face_0 ((128, 128)px)
#   ✅ jing_ang_003_clahe.jpg → face_0 ((128, 128)px)
#   ✅ jing_ang_004_clahe.jpg → face_0 ((128, 128)px)
#   ✅ jing_ang_005_clahe.jpg → face_0 ((128, 128)px)
#   ✅ jing_ang_006_clahe.jpg → face_0 ((128, 128)px)
#   ♻️ Cleared 6 old face ROI file(s) for jun_wei
#
# 👤 Processing jun_wei (6 preprocessed images):
#   ✅ jun_wei_001_clahe.jpg → face_0 ((128, 128)px)
#   ✅ jun_wei_002_clahe.jpg → face_0 ((128, 128)px)
#   ✅ jun_wei_003_clahe.jpg → face_0 ((128, 128)px)
#   ✅ jun_wei_004_clahe.jpg → face_0 ((128, 128)px)
#   ✅ jun_wei_005_clahe.jpg → face_0 ((128, 128)px)
#   ✅ jun_wei_006_clahe.jpg → face_0 ((128, 128)px)
#   ♻️ Cleared 11 old face ROI file(s) for kang_kai
#
# 👤 Processing kang_kai (11 preprocessed images):
#   ✅ kang_kai_001_clahe.jpg → face_0 ((128, 128)px)
#   ✅ kang_kai_002_clahe.jpg → face_0 ((128, 128)px)
#   ✅ kang_kai_003_clahe.jpg → face_0 ((128, 128)px)
#   ✅ kang_kai_004_clahe.jpg → face_0 ((128, 128)px)
#   ✅ kang_kai_004_clahe.jpg → face_1 ((128, 128)px)
#   ❌ No face detected: kang_kai_005_clahe.jpg
#   ✅ kang_kai_006_clahe.jpg → face_0 ((128, 128)px)
#   ✅ kang_kai_007_clahe.jpg → face_0 ((128, 128)px)
#   ✅ kang_kai_008_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: kang_kai_009_clahe.jpg
#   ✅ kang_kai_010_clahe.jpg → face_0 ((128, 128)px)
#   ✅ kang_kai_011_clahe.jpg → face_0 ((128, 128)px)
#   ✅ kang_kai_011_clahe.jpg → face_1 ((128, 128)px)
#   ♻️ Cleared 8 old face ROI file(s) for marion
#
# 👤 Processing marion (8 preprocessed images):
#   ✅ marion_001_clahe.jpg → face_0 ((128, 128)px)
#   ✅ marion_002_clahe.jpg → face_0 ((128, 128)px)
#   ✅ marion_003_clahe.jpg → face_0 ((128, 128)px)
#   ✅ marion_004_clahe.jpg → face_0 ((128, 128)px)
#   ✅ marion_005_clahe.jpg → face_0 ((128, 128)px)
#   ✅ marion_006_clahe.jpg → face_0 ((128, 128)px)
#   ✅ marion_007_clahe.jpg → face_0 ((128, 128)px)
#   ✅ marion_008_clahe.jpg → face_0 ((128, 128)px)
#   ♻️ Cleared 8 old face ROI file(s) for qi_xuan
#
# 👤 Processing qi_xuan (8 preprocessed images):
#   ✅ qi_xuan_001_clahe.jpg → face_0 ((128, 128)px)
#   ✅ qi_xuan_002_clahe.jpg → face_0 ((128, 128)px)
#   ✅ qi_xuan_003_clahe.jpg → face_0 ((128, 128)px)
#   ✅ qi_xuan_004_clahe.jpg → face_0 ((128, 128)px)
#   ✅ qi_xuan_005_clahe.jpg → face_0 ((128, 128)px)
#   ✅ qi_xuan_006_clahe.jpg → face_0 ((128, 128)px)
#   ✅ qi_xuan_007_clahe.jpg → face_0 ((128, 128)px)
#   ✅ qi_xuan_008_clahe.jpg → face_0 ((128, 128)px)
#   ♻️ Cleared 22 old face ROI file(s) for shuang_quan
#
# 👤 Processing shuang_quan (53 preprocessed images):
#   ❌ No face detected: shuang_quan_001_clahe.jpg
#   ✅ shuang_quan_002_clahe.jpg → face_0 ((128, 128)px)
#   ✅ shuang_quan_003_clahe.jpg → face_0 ((128, 128)px)
#   ✅ shuang_quan_004_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: shuang_quan_005_clahe.jpg
#   ✅ shuang_quan_006_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: shuang_quan_007_clahe.jpg
#   ✅ shuang_quan_008_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: shuang_quan_009_clahe.jpg
#   ✅ shuang_quan_010_clahe.jpg → face_0 ((128, 128)px)
#   ✅ shuang_quan_011_clahe.jpg → face_0 ((128, 128)px)
#   ✅ shuang_quan_012_clahe.jpg → face_0 ((128, 128)px)
#   ✅ shuang_quan_013_clahe.jpg → face_0 ((128, 128)px)
#   ✅ shuang_quan_014_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: shuang_quan_015_clahe.jpg
#   ❌ No face detected: shuang_quan_016_clahe.jpg
#   ✅ shuang_quan_017_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: shuang_quan_018_clahe.jpg
#   ❌ No face detected: shuang_quan_019_clahe.jpg
#   ❌ No face detected: shuang_quan_020_clahe.jpg
#   ❌ No face detected: shuang_quan_021_clahe.jpg
#   ❌ No face detected: shuang_quan_022_clahe.jpg
#   ✅ shuang_quan_023_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: shuang_quan_024_clahe.jpg
#   ❌ No face detected: shuang_quan_025_clahe.jpg
#   ❌ No face detected: shuang_quan_026_clahe.jpg
#   ❌ No face detected: shuang_quan_027_clahe.jpg
#   ❌ No face detected: shuang_quan_028_clahe.jpg
#   ✅ shuang_quan_029_clahe.jpg → face_0 ((128, 128)px)
#   ✅ shuang_quan_030_clahe.jpg → face_0 ((128, 128)px)
#   ✅ shuang_quan_031_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: shuang_quan_032_clahe.jpg
#   ✅ shuang_quan_033_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: shuang_quan_034_clahe.jpg
#   ❌ No face detected: shuang_quan_035_clahe.jpg
#   ❌ No face detected: shuang_quan_036_clahe.jpg
#   ❌ No face detected: shuang_quan_037_clahe.jpg
#   ✅ shuang_quan_038_clahe.jpg → face_0 ((128, 128)px)
#   ✅ shuang_quan_039_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: shuang_quan_040_clahe.jpg
#   ❌ No face detected: shuang_quan_041_clahe.jpg
#   ❌ No face detected: shuang_quan_042_clahe.jpg
#   ✅ shuang_quan_043_clahe.jpg → face_0 ((128, 128)px)
#   ✅ shuang_quan_044_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: shuang_quan_045_clahe.jpg
#   ❌ No face detected: shuang_quan_046_clahe.jpg
#   ❌ No face detected: shuang_quan_047_clahe.jpg
#   ✅ shuang_quan_048_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: shuang_quan_049_clahe.jpg
#   ❌ No face detected: shuang_quan_050_clahe.jpg
#   ✅ shuang_quan_051_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: shuang_quan_052_clahe.jpg
#   ❌ No face detected: shuang_quan_053_clahe.jpg
#   ♻️ Cleared 10 old face ROI file(s) for wee_xuan
#
# 👤 Processing wee_xuan (11 preprocessed images):
#   ✅ wee_xuan_001_clahe.jpg → face_0 ((128, 128)px)
#   ✅ wee_xuan_002_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: wee_xuan_003_clahe.jpg
#   ✅ wee_xuan_004_clahe.jpg → face_0 ((128, 128)px)
#   ✅ wee_xuan_005_clahe.jpg → face_0 ((128, 128)px)
#   ✅ wee_xuan_006_clahe.jpg → face_0 ((128, 128)px)
#   ✅ wee_xuan_007_clahe.jpg → face_0 ((128, 128)px)
#   ✅ wee_xuan_008_clahe.jpg → face_0 ((128, 128)px)
#   ✅ wee_xuan_009_clahe.jpg → face_0 ((128, 128)px)
#   ✅ wee_xuan_010_clahe.jpg → face_0 ((128, 128)px)
#   ✅ wee_xuan_011_clahe.jpg → face_0 ((128, 128)px)
#   ♻️ Cleared 8 old face ROI file(s) for xiang_yue
#
# 👤 Processing xiang_yue (10 preprocessed images):
#   ✅ xiang_yue_001_clahe.jpg → face_0 ((128, 128)px)
#   ✅ xiang_yue_002_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: xiang_yue_003_clahe.jpg
#   ✅ xiang_yue_004_clahe.jpg → face_0 ((128, 128)px)
#   ✅ xiang_yue_005_clahe.jpg → face_0 ((128, 128)px)
#   ✅ xiang_yue_006_clahe.jpg → face_0 ((128, 128)px)
#   ✅ xiang_yue_007_clahe.jpg → face_0 ((128, 128)px)
#   ✅ xiang_yue_008_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: xiang_yue_009_clahe.jpg
#   ✅ xiang_yue_010_clahe.jpg → face_0 ((128, 128)px)
#   ♻️ Cleared 5 old face ROI file(s) for xu_sheng
#
# 👤 Processing xu_sheng (16 preprocessed images):
#   ❌ No face detected: xu_sheng_001_clahe.jpg
#   ❌ No face detected: xu_sheng_002_clahe.jpg
#   ✅ xu_sheng_003_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: xu_sheng_004_clahe.jpg
#   ✅ xu_sheng_005_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: xu_sheng_006_clahe.jpg
#   ❌ No face detected: xu_sheng_007_clahe.jpg
#   ✅ xu_sheng_008_clahe.jpg → face_0 ((128, 128)px)
#   ✅ xu_sheng_009_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: xu_sheng_010_clahe.jpg
#   ❌ No face detected: xu_sheng_011_clahe.jpg
#   ❌ No face detected: xu_sheng_012_clahe.jpg
#   ❌ No face detected: xu_sheng_013_clahe.jpg
#   ❌ No face detected: xu_sheng_014_clahe.jpg
#   ❌ No face detected: xu_sheng_015_clahe.jpg
#   ✅ xu_sheng_016_clahe.jpg → face_0 ((128, 128)px)
#   ♻️ Cleared 22 old face ROI file(s) for yoke_hong
#
# 👤 Processing yoke_hong (34 preprocessed images):
#   ✅ yoke_hong_001_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: yoke_hong_002_clahe.jpg
#   ✅ yoke_hong_003_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: yoke_hong_004_clahe.jpg
#   ❌ No face detected: yoke_hong_005_clahe.jpg
#   ✅ yoke_hong_006_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: yoke_hong_007_clahe.jpg
#   ✅ yoke_hong_008_clahe.jpg → face_0 ((128, 128)px)
#   ✅ yoke_hong_009_clahe.jpg → face_0 ((128, 128)px)
#   ✅ yoke_hong_010_clahe.jpg → face_0 ((128, 128)px)
#   ✅ yoke_hong_011_clahe.jpg → face_0 ((128, 128)px)
#   ✅ yoke_hong_012_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: yoke_hong_013_clahe.jpg
#   ✅ yoke_hong_014_clahe.jpg → face_0 ((128, 128)px)
#   ✅ yoke_hong_015_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: yoke_hong_016_clahe.jpg
#   ❌ No face detected: yoke_hong_017_clahe.jpg
#   ✅ yoke_hong_018_clahe.jpg → face_0 ((128, 128)px)
#   ✅ yoke_hong_019_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: yoke_hong_020_clahe.jpg
#   ✅ yoke_hong_021_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: yoke_hong_022_clahe.jpg
#   ✅ yoke_hong_023_clahe.jpg → face_0 ((128, 128)px)
#   ✅ yoke_hong_024_clahe.jpg → face_0 ((128, 128)px)
#   ✅ yoke_hong_025_clahe.jpg → face_0 ((128, 128)px)
#   ✅ yoke_hong_026_clahe.jpg → face_0 ((128, 128)px)
#   ✅ yoke_hong_027_clahe.jpg → face_0 ((128, 128)px)
#   ✅ yoke_hong_028_clahe.jpg → face_0 ((128, 128)px)
#   ✅ yoke_hong_029_clahe.jpg → face_0 ((128, 128)px)
#   ✅ yoke_hong_030_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: yoke_hong_031_clahe.jpg
#   ✅ yoke_hong_032_clahe.jpg → face_0 ((128, 128)px)
#   ❌ No face detected: yoke_hong_033_clahe.jpg
#   ❌ No face detected: yoke_hong_034_clahe.jpg
#   ♻️ Cleared 10 old face ROI file(s) for yong_kang
#
# 👤 Processing yong_kang (9 preprocessed images):
#   ✅ yong_kang_001_clahe.jpg → face_0 ((128, 128)px)
#   ✅ yong_kang_002_clahe.jpg → face_0 ((128, 128)px)
#   ✅ yong_kang_003_clahe.jpg → face_0 ((128, 128)px)
#   ✅ yong_kang_004_clahe.jpg → face_0 ((128, 128)px)
#   ✅ yong_kang_005_clahe.jpg → face_0 ((128, 128)px)
#   ✅ yong_kang_006_clahe.jpg → face_0 ((128, 128)px)
#   ✅ yong_kang_006_clahe.jpg → face_1 ((128, 128)px)
#   ✅ yong_kang_007_clahe.jpg → face_0 ((128, 128)px)
#   ✅ yong_kang_008_clahe.jpg → face_0 ((128, 128)px)
#   ✅ yong_kang_009_clahe.jpg → face_0 ((128, 128)px)
#   ♻️ Cleared 9 old face ROI file(s) for zi_herng
#
# 👤 Processing zi_herng (8 preprocessed images):
#   ✅ zi_herng_001_clahe.jpg → face_0 ((128, 128)px)
#   ✅ zi_herng_002_clahe.jpg → face_0 ((128, 128)px)
#   ✅ zi_herng_003_clahe.jpg → face_0 ((128, 128)px)
#   ✅ zi_herng_004_clahe.jpg → face_0 ((128, 128)px)
#   ✅ zi_herng_005_clahe.jpg → face_0 ((128, 128)px)
#   ✅ zi_herng_006_clahe.jpg → face_0 ((128, 128)px)
#   ✅ zi_herng_006_clahe.jpg → face_1 ((128, 128)px)
#   ✅ zi_herng_007_clahe.jpg → face_0 ((128, 128)px)
#   ✅ zi_herng_008_clahe.jpg → face_0 ((128, 128)px)
#
# ✨ FACE ROI EXTRACTION COMPLETE!
#   ✅ Images processed: 235
#   👤 Faces extracted: 243
#   ❌ Failed: 126
#   📁 Output: ..\data\faces_detected
#
# 📊 EXTRACTION SUMMARY:
# Images processed: 235
# Faces extracted: 243
# Failed: 126

# %% [markdown]
# # Step 4: Post-process Extracted Faces
#
# Apply final grayscale conversion and CLAHE enhancement to extracted faces for optimal quality:

# %%
class FacePostProcessor:
    def __init__(self, clahe_clip_limit=CLAHE_CLIP_LIMIT, clahe_grid_size=CLAHE_GRID_SIZE, target_size=OUTPUT_SIZE):
        """Initialize post-processor for extracted faces"""
        self.clahe = cv2.createCLAHE(clipLimit=clahe_clip_limit, tileGridSize=clahe_grid_size)
        self.target_size = target_size
        
        print(f"✅ Face post-processor initialized")
        print(f"   • Target size: {target_size}")
        print(f"   • CLAHE clip limit: {clahe_clip_limit}")
        print(f"   • CLAHE grid size: {clahe_grid_size}")
    
    def post_process_face(self, face_image):
        """Apply CLAHE enhancement only and return final image."""
        # Always work in grayscale before CLAHE.
        if len(face_image.shape) == 3:
            gray = cv2.cvtColor(face_image, cv2.COLOR_BGR2GRAY)
        else:
            gray = face_image
        
        # Apply CLAHE enhancement.
        clahe_face = self.clahe.apply(gray)
        
        # Resize to target size if needed.
        if clahe_face.shape[:2] != self.target_size:
            clahe_face = cv2.resize(clahe_face, self.target_size)
        
        return clahe_face
    
    def post_process_folder(self, input_folder, output_folder):
        """Post-process all extracted faces"""
        # Verify folders exist
        if not os.path.exists(input_folder):
            print(f"❌ Input folder not found: {input_folder}")
            return 0, 0
        
        if not os.path.exists(output_folder):
            print(f"❌ Output folder not found: {output_folder}")
            return 0, 0
        
        # Get person folders
        person_folders = [f for f in os.listdir(input_folder) 
                         if os.path.isdir(os.path.join(input_folder, f))]
        
        total_processed = 0
        total_failed = 0
        
        for person in person_folders:
            person_input_path = os.path.join(input_folder, person)
            person_output_path = os.path.join(output_folder, person)
            if not os.path.exists(person_output_path):
                os.makedirs(person_output_path, exist_ok=True)

            old_outputs = [f for f in os.listdir(person_output_path)
                           if Path(f).suffix.lower() in {'.jpg', '.jpeg', '.png'}]
            for old_file in old_outputs:
                os.remove(os.path.join(person_output_path, old_file))
            if old_outputs:
                print(f"Cleared {len(old_outputs)} old final-processed file(s) for {person}")
            
            # Get face images
            face_files = [f for f in os.listdir(person_input_path) 
                         if f.lower().endswith('.jpg') and '_face_' in f]
            
            # Skip folders with no face images
            if not face_files:
                print(f"  ⚠️ No face images found for {person} — skipped")
                continue
            
            print(f"\n👤 Post-processing {person} ({len(face_files)} faces):")
            
            for face_file in face_files:
                input_path = os.path.join(person_input_path, face_file)
                face_image = cv2.imread(input_path, cv2.IMREAD_GRAYSCALE)
                
                if face_image is None:
                    print(f"  ❌ Failed to read: {face_file}")
                    total_failed += 1
                    continue
                
                # Post-process the face
                processed_face = self.post_process_face(face_image)
                
                # Save processed face
                base_name = Path(face_file).stem
                output_filename = f"{base_name}_clahe.jpg"
                output_path = os.path.join(person_output_path, output_filename)
                cv2.imwrite(output_path, processed_face, [cv2.IMWRITE_JPEG_QUALITY, IMAGE_QUALITY])
                
                total_processed += 1
                print(f"  ✅ {face_file} → CLAHE ({self.target_size}px)")
        
        print(f"\n✨ POST-PROCESSING COMPLETE!")
        print(f"  ✅ Faces processed: {total_processed}")
        print(f"  ❌ Failed: {total_failed}")
        print(f"  📁 Output: {output_folder}")
        
        return total_processed, total_failed

# Initialize post-processor
face_post_processor = FacePostProcessor()
print("⚡ Face post-processor ready!")
# Out:
# ✅ Face post-processor initialized
#    • Target size: (128, 128)
#    • CLAHE clip limit: 2.0
#    • CLAHE grid size: (8, 8)
# ⚡ Face post-processor ready!

# %%
def post_process_extracted_faces():
    """Apply final post-processing to extracted face ROIs."""
    print("⚡ STARTING FACE POST-PROCESSING")
    print("=" * 50)
    
    if not os.path.exists(FACES_DETECTED_FOLDER):
        print("❌ Face detection folder not found! Please run face extraction first.")
        return
    
    # Post-process all extracted faces
    stats = face_post_processor.post_process_folder(FACES_DETECTED_FOLDER, FINAL_PROCESSED_FOLDER)
    
    print("\n📊 POST-PROCESSING SUMMARY:")
    print(f"Faces processed: {stats[0]}")
    print(f"Failed: {stats[1]}")
    print(f"📁 Final output: {FINAL_PROCESSED_FOLDER}")
    
    return stats

# Run face post-processing
post_processing_stats = post_process_extracted_faces()
# Out:
# ⚡ STARTING FACE POST-PROCESSING
# ==================================================
#
# 👤 Post-processing benjamin (13 faces):
#   ✅ benjamin_001_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ benjamin_005_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ benjamin_006_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ benjamin_007_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ benjamin_013_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ benjamin_015_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ benjamin_016_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ benjamin_018_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ benjamin_021_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ benjamin_024_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ benjamin_025_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ benjamin_026_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ benjamin_027_clahe_face_0.jpg → CLAHE ((128, 128)px)
#
# 👤 Post-processing chern_tak (11 faces):
#   ✅ chern_tak_002_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ chern_tak_003_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ chern_tak_006_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ chern_tak_008_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ chern_tak_013_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ chern_tak_020_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ chern_tak_021_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ chern_tak_022_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ chern_tak_022_clahe_face_1.jpg → CLAHE ((128, 128)px)
#   ✅ chern_tak_023_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ chern_tak_024_clahe_face_0.jpg → CLAHE ((128, 128)px)
#
# 👤 Post-processing chillien (9 faces):
#   ✅ chillien_001_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ chillien_002_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ chillien_003_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ chillien_005_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ chillien_006_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ chillien_007_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ chillien_008_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ chillien_009_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ chillien_010_clahe_face_0.jpg → CLAHE ((128, 128)px)
#
# 👤 Post-processing daniel (38 faces):
#   ✅ daniel_001_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ daniel_003_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ daniel_005_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ daniel_006_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ daniel_009_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ daniel_010_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ daniel_012_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ daniel_013_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ daniel_016_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ daniel_017_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ daniel_018_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ daniel_019_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ daniel_024_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ daniel_025_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ daniel_026_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ daniel_027_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ daniel_028_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ daniel_028_clahe_face_1.jpg → CLAHE ((128, 128)px)
#   ✅ daniel_030_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ daniel_031_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ daniel_034_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ daniel_035_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ daniel_038_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ daniel_041_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ daniel_043_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ daniel_044_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ daniel_044_clahe_face_1.jpg → CLAHE ((128, 128)px)
#   ✅ daniel_045_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ daniel_047_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ daniel_048_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ daniel_051_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ daniel_052_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ daniel_052_clahe_face_1.jpg → CLAHE ((128, 128)px)
#   ✅ daniel_054_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ daniel_055_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ daniel_056_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ daniel_057_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ daniel_058_clahe_face_0.jpg → CLAHE ((128, 128)px)
#
# 👤 Post-processing Dr.Nurul (8 faces):
#   ✅ Dr.Nurul_001_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ Dr.Nurul_002_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ Dr.Nurul_003_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ Dr.Nurul_004_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ Dr.Nurul_005_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ Dr.Nurul_006_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ Dr.Nurul_007_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ Dr.Nurul_008_clahe_face_0.jpg → CLAHE ((128, 128)px)
#
# 👤 Post-processing dylan (23 faces):
#   ✅ dylan_001_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ dylan_002_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ dylan_003_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ dylan_004_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ dylan_006_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ dylan_007_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ dylan_008_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ dylan_009_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ dylan_010_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ dylan_011_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ dylan_012_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ dylan_013_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ dylan_014_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ dylan_015_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ dylan_017_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ dylan_018_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ dylan_021_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ dylan_022_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ dylan_023_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ dylan_024_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ dylan_026_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ dylan_027_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ dylan_028_clahe_face_0.jpg → CLAHE ((128, 128)px)
#
# 👤 Post-processing han_soon (8 faces):
#   ✅ han_soon_001_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ han_soon_002_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ han_soon_003_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ han_soon_004_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ han_soon_005_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ han_soon_006_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ han_soon_007_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ han_soon_008_clahe_face_0.jpg → CLAHE ((128, 128)px)
#
# 👤 Post-processing harry (7 faces):
#   ✅ harry_001_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ harry_002_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ harry_003_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ harry_004_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ harry_005_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ harry_006_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ harry_007_clahe_face_0.jpg → CLAHE ((128, 128)px)
#
# 👤 Post-processing isaac (1 faces):
#   ✅ isaac_006_clahe_face_0.jpg → CLAHE ((128, 128)px)
#
# 👤 Post-processing jing_ang (6 faces):
#   ✅ jing_ang_001_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ jing_ang_002_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ jing_ang_003_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ jing_ang_004_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ jing_ang_005_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ jing_ang_006_clahe_face_0.jpg → CLAHE ((128, 128)px)
#
# 👤 Post-processing jun_wei (6 faces):
#   ✅ jun_wei_001_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ jun_wei_002_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ jun_wei_003_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ jun_wei_004_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ jun_wei_005_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ jun_wei_006_clahe_face_0.jpg → CLAHE ((128, 128)px)
#
# 👤 Post-processing kang_kai (11 faces):
#   ✅ kang_kai_001_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ kang_kai_002_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ kang_kai_003_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ kang_kai_004_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ kang_kai_004_clahe_face_1.jpg → CLAHE ((128, 128)px)
#   ✅ kang_kai_006_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ kang_kai_007_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ kang_kai_008_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ kang_kai_010_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ kang_kai_011_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ kang_kai_011_clahe_face_1.jpg → CLAHE ((128, 128)px)
#
# 👤 Post-processing marion (8 faces):
#   ✅ marion_001_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ marion_002_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ marion_003_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ marion_004_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ marion_005_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ marion_006_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ marion_007_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ marion_008_clahe_face_0.jpg → CLAHE ((128, 128)px)
#
# 👤 Post-processing qi_xuan (8 faces):
#   ✅ qi_xuan_001_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ qi_xuan_002_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ qi_xuan_003_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ qi_xuan_004_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ qi_xuan_005_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ qi_xuan_006_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ qi_xuan_007_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ qi_xuan_008_clahe_face_0.jpg → CLAHE ((128, 128)px)
#
# 👤 Post-processing shuang_quan (22 faces):
#   ✅ shuang_quan_002_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ shuang_quan_003_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ shuang_quan_004_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ shuang_quan_006_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ shuang_quan_008_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ shuang_quan_010_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ shuang_quan_011_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ shuang_quan_012_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ shuang_quan_013_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ shuang_quan_014_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ shuang_quan_017_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ shuang_quan_023_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ shuang_quan_029_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ shuang_quan_030_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ shuang_quan_031_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ shuang_quan_033_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ shuang_quan_038_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ shuang_quan_039_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ shuang_quan_043_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ shuang_quan_044_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ shuang_quan_048_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ shuang_quan_051_clahe_face_0.jpg → CLAHE ((128, 128)px)
#
# 👤 Post-processing wee_xuan (10 faces):
#   ✅ wee_xuan_001_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ wee_xuan_002_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ wee_xuan_004_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ wee_xuan_005_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ wee_xuan_006_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ wee_xuan_007_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ wee_xuan_008_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ wee_xuan_009_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ wee_xuan_010_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ wee_xuan_011_clahe_face_0.jpg → CLAHE ((128, 128)px)
#
# 👤 Post-processing xiang_yue (8 faces):
#   ✅ xiang_yue_001_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ xiang_yue_002_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ xiang_yue_004_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ xiang_yue_005_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ xiang_yue_006_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ xiang_yue_007_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ xiang_yue_008_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ xiang_yue_010_clahe_face_0.jpg → CLAHE ((128, 128)px)
#
# 👤 Post-processing xu_sheng (5 faces):
#   ✅ xu_sheng_003_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ xu_sheng_005_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ xu_sheng_008_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ xu_sheng_009_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ xu_sheng_016_clahe_face_0.jpg → CLAHE ((128, 128)px)
#
# 👤 Post-processing yoke_hong (22 faces):
#   ✅ yoke_hong_001_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ yoke_hong_003_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ yoke_hong_006_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ yoke_hong_008_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ yoke_hong_009_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ yoke_hong_010_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ yoke_hong_011_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ yoke_hong_012_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ yoke_hong_014_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ yoke_hong_015_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ yoke_hong_018_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ yoke_hong_019_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ yoke_hong_021_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ yoke_hong_023_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ yoke_hong_024_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ yoke_hong_025_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ yoke_hong_026_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ yoke_hong_027_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ yoke_hong_028_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ yoke_hong_029_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ yoke_hong_030_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ yoke_hong_032_clahe_face_0.jpg → CLAHE ((128, 128)px)
#
# 👤 Post-processing yong_kang (10 faces):
#   ✅ yong_kang_001_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ yong_kang_002_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ yong_kang_003_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ yong_kang_004_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ yong_kang_005_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ yong_kang_006_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ yong_kang_006_clahe_face_1.jpg → CLAHE ((128, 128)px)
#   ✅ yong_kang_007_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ yong_kang_008_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ yong_kang_009_clahe_face_0.jpg → CLAHE ((128, 128)px)
#
# 👤 Post-processing zi_herng (9 faces):
#   ✅ zi_herng_001_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ zi_herng_002_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ zi_herng_003_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ zi_herng_004_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ zi_herng_005_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ zi_herng_006_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ zi_herng_006_clahe_face_1.jpg → CLAHE ((128, 128)px)
#   ✅ zi_herng_007_clahe_face_0.jpg → CLAHE ((128, 128)px)
#   ✅ zi_herng_008_clahe_face_0.jpg → CLAHE ((128, 128)px)
#
# ✨ POST-PROCESSING COMPLETE!
#   ✅ Faces processed: 243
#   ❌ Failed: 0
#   📁 Output: ..\data\final_processed
#
# 📊 POST-PROCESSING SUMMARY:
# Faces processed: 243
# Failed: 0
# 📁 Final output: ..\data\final_processed

# %%
def process_test_raw_faces_to_test_processed():
    """Process test_raw using dlib HOG face detection and save to test_processed."""
    print("🧪 STARTING TEST DATA PROCESSING (dlib HOG)")
    print("=" * 60)

    if not os.path.exists(TEST_RAW_FOLDER):
        print(f"❌ Test raw folder not found: {TEST_RAW_FOLDER}")
        return 0, 0, 0

    os.makedirs(TEST_PROCESSED_FOLDER, exist_ok=True)

    person_folders = sorted([
        p for p in os.listdir(TEST_RAW_FOLDER)
        if os.path.isdir(os.path.join(TEST_RAW_FOLDER, p))
    ])

    if not person_folders:
        print("❌ No person folders found in test_raw.")
        return 0, 0, 0

    total_saved = 0
    total_failed = 0
    total_no_face = 0

    for person in person_folders:
        person_input = os.path.join(TEST_RAW_FOLDER, person)
        person_output = os.path.join(TEST_PROCESSED_FOLDER, person)
        os.makedirs(person_output, exist_ok=True)

        old_outputs = [
            f for f in os.listdir(person_output)
            if Path(f).suffix.lower() in {'.jpg', '.jpeg', '.png'}
        ]
        for old_file in old_outputs:
            os.remove(os.path.join(person_output, old_file))

        image_files = sorted([
            f for f in os.listdir(person_input)
            if Path(f).suffix.lower() in {'.jpg', '.jpeg', '.png'}
        ])

        if not image_files:
            print(f"\n👤 {person}: no test images found")
            continue

        print(f"\n👤 Processing {person} ({len(image_files)} test images):")

        for image_file in image_files:
            input_path = os.path.join(person_input, image_file)
            image = cv2.imread(input_path)
            if image is None:
                print(f"  ❌ Failed to read: {image_file}")
                total_failed += 1
                continue

            gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
            clahe_gray = preprocessor.preprocess_image(gray)

            # Use the same dlib HOG detector path as training face extraction.
            faces = roi_extractor.detect_faces_dlib(clahe_gray)
            if not faces:
                print(f"  ❌ No face detected (dlib HOG): {image_file}")
                total_no_face += 1
                continue

            # Keep the largest face for a stable single test sample per image.
            x, y, w, h = max(faces, key=lambda t: t[2] * t[3])
            roi, _ = roi_extractor.extract_roi_with_padding(clahe_gray, x, y, w, h)
            processed_face = face_post_processor.post_process_face(roi)

            base_name = Path(image_file).stem
            output_file = os.path.join(person_output, f"{base_name}_test_processed.jpg")
            cv2.imwrite(output_file, processed_face, [cv2.IMWRITE_JPEG_QUALITY, IMAGE_QUALITY])
            total_saved += 1
            print(f"  ✅ {image_file} → {Path(output_file).name}")

    print("\n✨ TEST DATA PROCESSING COMPLETE!")
    print(f"  ✅ Saved:      {total_saved}")
    print(f"  ❌ Read failed:{total_failed}")
    print(f"  ❌ No face:    {total_no_face}")
    print(f"  📁 Output:     {TEST_PROCESSED_FOLDER}")

    return total_saved, total_failed, total_no_face


# Run test processing
test_processing_stats = process_test_raw_faces_to_test_processed()
# Out:
# 🧪 STARTING TEST DATA PROCESSING (dlib HOG)
# ============================================================
#
# 👤 Processing Dr.Nurul (3 test images):
#   ✅ Dr.Nurul_test_001.jpg → Dr.Nurul_test_001_test_processed.jpg
#   ✅ Dr.Nurul_test_002.jpg → Dr.Nurul_test_002_test_processed.jpg
#   ✅ Dr.Nurul_test_003.jpg → Dr.Nurul_test_003_test_processed.jpg
#
# 👤 Processing benjamin (12 test images):
#   ✅ benjamin_test_001.jpg → benjamin_test_001_test_processed.jpg
#   ❌ No face detected (dlib HOG): benjamin_test_002.jpg
#   ✅ benjamin_test_003.jpg → benjamin_test_003_test_processed.jpg
#   ✅ benjamin_test_004.jpg → benjamin_test_004_test_processed.jpg
#   ❌ No face detected (dlib HOG): benjamin_test_005.jpg
#   ✅ benjamin_test_006.jpg → benjamin_test_006_test_processed.jpg
#   ❌ No face detected (dlib HOG): benjamin_test_007.jpg
#   ❌ No face detected (dlib HOG): benjamin_test_008.jpg
#   ✅ benjamin_test_009.jpg → benjamin_test_009_test_processed.jpg
#   ❌ No face detected (dlib HOG): benjamin_test_010.jpg
#   ✅ benjamin_test_011.jpg → benjamin_test_011_test_processed.jpg
#   ✅ benjamin_test_012.jpg → benjamin_test_012_test_processed.jpg
#
# 👤 Processing chern_tak (11 test images):
#   ✅ chern_tak_test_001.jpg → chern_tak_test_001_test_processed.jpg
#   ❌ No face detected (dlib HOG): chern_tak_test_002.jpg
#   ✅ chern_tak_test_003.jpg → chern_tak_test_003_test_processed.jpg
#   ❌ No face detected (dlib HOG): chern_tak_test_004.jpg
#   ❌ No face detected (dlib HOG): chern_tak_test_005.jpg
#   ✅ chern_tak_test_006.jpg → chern_tak_test_006_test_processed.jpg
#   ✅ chern_tak_test_007.jpg → chern_tak_test_007_test_processed.jpg
#   ❌ No face detected (dlib HOG): chern_tak_test_008.jpg
#   ❌ No face detected (dlib HOG): chern_tak_test_009.jpg
#   ❌ No face detected (dlib HOG): chern_tak_test_010.jpg
#   ❌ No face detected (dlib HOG): chern_tak_test_011.jpg
#
# 👤 Processing chillien (4 test images):
#   ✅ chillien_test_001.jpg → chillien_test_001_test_processed.jpg
#   ✅ chillien_test_002.jpg → chillien_test_002_test_processed.jpg
#   ✅ chillien_test_003.jpg → chillien_test_003_test_processed.jpg
#   ❌ No face detected (dlib HOG): chillien_test_004.jpg
#
# 👤 Processing daniel (25 test images):
#   ✅ daniel_test_001.jpg → daniel_test_001_test_processed.jpg
#   ✅ daniel_test_002.jpg → daniel_test_002_test_processed.jpg
#   ❌ No face detected (dlib HOG): daniel_test_003.jpg
#   ✅ daniel_test_004.jpg → daniel_test_004_test_processed.jpg
#   ✅ daniel_test_005.jpg → daniel_test_005_test_processed.jpg
#   ✅ daniel_test_006.jpg → daniel_test_006_test_processed.jpg
#   ✅ daniel_test_007.jpg → daniel_test_007_test_processed.jpg
#   ❌ No face detected (dlib HOG): daniel_test_008.jpg
#   ✅ daniel_test_009.jpg → daniel_test_009_test_processed.jpg
#   ✅ daniel_test_010.jpg → daniel_test_010_test_processed.jpg
#   ✅ daniel_test_011.jpg → daniel_test_011_test_processed.jpg
#   ✅ daniel_test_012.jpg → daniel_test_012_test_processed.jpg
#   ❌ No face detected (dlib HOG): daniel_test_013.jpg
#   ✅ daniel_test_014.jpg → daniel_test_014_test_processed.jpg
#   ✅ daniel_test_015.jpg → daniel_test_015_test_processed.jpg
#   ✅ daniel_test_016.jpg → daniel_test_016_test_processed.jpg
#   ✅ daniel_test_017.jpg → daniel_test_017_test_processed.jpg
#   ❌ No face detected (dlib HOG): daniel_test_018.jpg
#   ✅ daniel_test_019.jpg → daniel_test_019_test_processed.jpg
#   ❌ No face detected (dlib HOG): daniel_test_020.jpg
#   ❌ No face detected (dlib HOG): daniel_test_021.jpg
#   ✅ daniel_test_022.jpg → daniel_test_022_test_processed.jpg
#   ✅ daniel_test_023.jpg → daniel_test_023_test_processed.jpg
#   ✅ daniel_test_024.jpg → daniel_test_024_test_processed.jpg
#   ❌ No face detected (dlib HOG): daniel_test_025.jpg
#
# 👤 Processing dylan (12 test images):
#   ✅ dylan_test_001.jpg → dylan_test_001_test_processed.jpg
#   ✅ dylan_test_002.jpg → dylan_test_002_test_processed.jpg
#   ✅ dylan_test_003.jpg → dylan_test_003_test_processed.jpg
#   ✅ dylan_test_004.jpg → dylan_test_004_test_processed.jpg
#   ❌ No face detected (dlib HOG): dylan_test_005.jpg
#   ✅ dylan_test_006.jpg → dylan_test_006_test_processed.jpg
#   ❌ No face detected (dlib HOG): dylan_test_007.jpg
#   ✅ dylan_test_008.jpg → dylan_test_008_test_processed.jpg
#   ✅ dylan_test_009.jpg → dylan_test_009_test_processed.jpg
#   ✅ dylan_test_010.jpg → dylan_test_010_test_processed.jpg
#   ✅ dylan_test_011.jpg → dylan_test_011_test_processed.jpg
#   ✅ dylan_test_012.jpg → dylan_test_012_test_processed.jpg
#
# 👤 Processing han_soon (3 test images):
#   ❌ No face detected (dlib HOG): han_soon_test_001.jpg
#   ✅ han_soon_test_002.jpg → han_soon_test_002_test_processed.jpg
#   ✅ han_soon_test_003.jpg → han_soon_test_003_test_processed.jpg
#
# 👤 Processing harry (3 test images):
#   ✅ harry_test_001.jpg → harry_test_001_test_processed.jpg
#   ✅ harry_test_002.jpg → harry_test_002_test_processed.jpg
#   ✅ harry_test_003.jpg → harry_test_003_test_processed.jpg
#
# 👤 Processing isaac (3 test images):
#   ❌ No face detected (dlib HOG): isaac_test_001.jpg
#   ✅ isaac_test_002.jpg → isaac_test_002_test_processed.jpg
#   ❌ No face detected (dlib HOG): isaac_test_003.jpg
#
# 👤 Processing jing_ang (3 test images):
#   ✅ jing_ang_test_001.jpg → jing_ang_test_001_test_processed.jpg
#   ✅ jing_ang_test_002.jpg → jing_ang_test_002_test_processed.jpg
#   ✅ jing_ang_test_003.jpg → jing_ang_test_003_test_processed.jpg
#
# 👤 Processing jun_wei (3 test images):
#   ✅ jun_wei_test_001.jpg → jun_wei_test_001_test_processed.jpg
#   ✅ jun_wei_test_002.jpg → jun_wei_test_002_test_processed.jpg
#   ✅ jun_wei_test_003.jpg → jun_wei_test_003_test_processed.jpg
#
# 👤 Processing kang_kai (5 test images):
#   ✅ kang_kai_test_001.jpg → kang_kai_test_001_test_processed.jpg
#   ✅ kang_kai_test_002.jpg → kang_kai_test_002_test_processed.jpg
#   ✅ kang_kai_test_003.jpg → kang_kai_test_003_test_processed.jpg
#   ✅ kang_kai_test_004.jpg → kang_kai_test_004_test_processed.jpg
#   ✅ kang_kai_test_005.jpg → kang_kai_test_005_test_processed.jpg
#
# 👤 Processing marion (3 test images):
#   ✅ marion_test_001.jpg → marion_test_001_test_processed.jpg
#   ✅ marion_test_002.jpg → marion_test_002_test_processed.jpg
#   ❌ No face detected (dlib HOG): marion_test_003.jpg
#
# 👤 Processing qi_xuan (3 test images):
#   ✅ qi_xuan_test_001.jpg → qi_xuan_test_001_test_processed.jpg
#   ✅ qi_xuan_test_002.jpg → qi_xuan_test_002_test_processed.jpg
#   ✅ qi_xuan_test_003.jpg → qi_xuan_test_003_test_processed.jpg
#
# 👤 Processing shuang_quan (22 test images):
#   ✅ shuang_quan_test_001.jpg → shuang_quan_test_001_test_processed.jpg
#   ❌ No face detected (dlib HOG): shuang_quan_test_002.jpg
#   ✅ shuang_quan_test_003.jpg → shuang_quan_test_003_test_processed.jpg
#   ❌ No face detected (dlib HOG): shuang_quan_test_004.jpg
#   ❌ No face detected (dlib HOG): shuang_quan_test_005.jpg
#   ❌ No face detected (dlib HOG): shuang_quan_test_006.jpg
#   ✅ shuang_quan_test_007.jpg → shuang_quan_test_007_test_processed.jpg
#   ✅ shuang_quan_test_008.jpg → shuang_quan_test_008_test_processed.jpg
#   ❌ No face detected (dlib HOG): shuang_quan_test_009.jpg
#   ❌ No face detected (dlib HOG): shuang_quan_test_010.jpg
#   ✅ shuang_quan_test_011.jpg → shuang_quan_test_011_test_processed.jpg
#   ❌ No face detected (dlib HOG): shuang_quan_test_012.jpg
#   ❌ No face detected (dlib HOG): shuang_quan_test_013.jpg
#   ❌ No face detected (dlib HOG): shuang_quan_test_014.jpg
#   ❌ No face detected (dlib HOG): shuang_quan_test_015.jpg
#   ❌ No face detected (dlib HOG): shuang_quan_test_016.jpg
#   ✅ shuang_quan_test_017.jpg → shuang_quan_test_017_test_processed.jpg
#   ❌ No face detected (dlib HOG): shuang_quan_test_018.jpg
#   ❌ No face detected (dlib HOG): shuang_quan_test_019.jpg
#   ✅ shuang_quan_test_020.jpg → shuang_quan_test_020_test_processed.jpg
#   ❌ No face detected (dlib HOG): shuang_quan_test_021.jpg
#   ✅ shuang_quan_test_022.jpg → shuang_quan_test_022_test_processed.jpg
#
# 👤 Processing wee_xuan (5 test images):
#   ✅ wee_xuan_test_001.jpg → wee_xuan_test_001_test_processed.jpg
#   ✅ wee_xuan_test_002.jpg → wee_xuan_test_002_test_processed.jpg
#   ✅ wee_xuan_test_003.jpg → wee_xuan_test_003_test_processed.jpg
#   ❌ No face detected (dlib HOG): wee_xuan_test_004.jpg
#   ❌ No face detected (dlib HOG): wee_xuan_test_005.jpg
#
# 👤 Processing xiang_yue (4 test images):
#   ✅ xiang_yue_test_001.jpg → xiang_yue_test_001_test_processed.jpg
#   ✅ xiang_yue_test_002.jpg → xiang_yue_test_002_test_processed.jpg
#   ✅ xiang_yue_test_003.jpg → xiang_yue_test_003_test_processed.jpg
#   ✅ xiang_yue_test_004.jpg → xiang_yue_test_004_test_processed.jpg
#
# 👤 Processing xu_sheng (7 test images):
#   ❌ No face detected (dlib HOG): xu_sheng_test_001.jpg
#   ✅ xu_sheng_test_002.jpg → xu_sheng_test_002_test_processed.jpg
#   ❌ No face detected (dlib HOG): xu_sheng_test_003.jpg
#   ✅ xu_sheng_test_004.jpg → xu_sheng_test_004_test_processed.jpg
#   ❌ No face detected (dlib HOG): xu_sheng_test_005.jpg
#   ✅ xu_sheng_test_006.jpg → xu_sheng_test_006_test_processed.jpg
#   ❌ No face detected (dlib HOG): xu_sheng_test_007.jpg
#
# 👤 Processing yoke_hong (15 test images):
#   ✅ yoke_hong_test_001.jpg → yoke_hong_test_001_test_processed.jpg
#   ❌ No face detected (dlib HOG): yoke_hong_test_002.jpg
#   ✅ yoke_hong_test_003.jpg → yoke_hong_test_003_test_processed.jpg
#   ✅ yoke_hong_test_004.jpg → yoke_hong_test_004_test_processed.jpg
#   ✅ yoke_hong_test_005.jpg → yoke_hong_test_005_test_processed.jpg
#   ✅ yoke_hong_test_006.jpg → yoke_hong_test_006_test_processed.jpg
#   ❌ No face detected (dlib HOG): yoke_hong_test_007.jpg
#   ✅ yoke_hong_test_008.jpg → yoke_hong_test_008_test_processed.jpg
#   ✅ yoke_hong_test_009.jpg → yoke_hong_test_009_test_processed.jpg
#   ✅ yoke_hong_test_010.jpg → yoke_hong_test_010_test_processed.jpg
#   ❌ No face detected (dlib HOG): yoke_hong_test_011.jpg
#   ✅ yoke_hong_test_012.jpg → yoke_hong_test_012_test_processed.jpg
#   ✅ yoke_hong_test_013.jpg → yoke_hong_test_013_test_processed.jpg
#   ❌ No face detected (dlib HOG): yoke_hong_test_014.jpg
#   ❌ No face detected (dlib HOG): yoke_hong_test_015.jpg
#
# 👤 Processing yong_kang (4 test images):
#   ✅ yong_kang_test_001.jpg → yong_kang_test_001_test_processed.jpg
#   ✅ yong_kang_test_002.jpg → yong_kang_test_002_test_processed.jpg
#   ✅ yong_kang_test_003.jpg → yong_kang_test_003_test_processed.jpg
#   ✅ yong_kang_test_004.jpg → yong_kang_test_004_test_processed.jpg
#
# 👤 Processing zi_herng (3 test images):
#   ✅ zi_herng_test_001.jpg → zi_herng_test_001_test_processed.jpg
#   ✅ zi_herng_test_002.jpg → zi_herng_test_002_test_processed.jpg
#   ✅ zi_herng_test_003.jpg → zi_herng_test_003_test_processed.jpg
#
# ✨ TEST DATA PROCESSING COMPLETE!
#   ✅ Saved:      102
#   ❌ Read failed:0
#   ❌ No face:    51
#   📁 Output:     ..\data\test_processed

# %% [markdown]
# # Step 5: Process Test Data with dlib HOG
#
# Process test_raw with the same dlib HOG face-cropping path and save to test_processed:

# %% [markdown]
# # 📊 Dataset Analysis After Preprocessing
#
# Compare per-person image counts at each pipeline stage (Raw → Converted → Final Processed) and see the overall retention rate after blur filtering and face detection.

# %%
def analyze_preprocessed_dataset():
    """
    Compare per-person image counts at each pipeline stage:
    Raw → Converted (blur filtered) → Final Processed (face crops).
    Shows retention rates and flags people with low retention.
    """
    print("📊 DATASET ANALYSIS AFTER PREPROCESSING")
    print("=" * 60)

    def count_per_person(folder, extensions=None):
        if extensions is None:
            extensions = {'.jpg', '.jpeg', '.png'}
        result = {}
        if not os.path.exists(folder):
            return result
        for person in sorted(os.listdir(folder)):
            person_path = os.path.join(folder, person)
            if os.path.isdir(person_path):
                files = [f for f in os.listdir(person_path)
                         if Path(f).suffix.lower() in extensions]
                result[person] = len(files)
        return result

    raw_counts   = count_per_person(RAW_FOLDER, {'.jpg', '.jpeg', '.png', '.heic'})
    conv_counts  = count_per_person(CONVERTED_FOLDER)
    final_counts = count_per_person(FINAL_PROCESSED_FOLDER)

    all_people = sorted(set(raw_counts) | set(conv_counts) | set(final_counts))

    if not all_people:
        print("❌ No data found. Run the pipeline (Steps 1–4) first.")
        return

    # --- Table ---
    print(f"\n  {'Person':<16} {'Raw':>5} {'Converted':>10} {'Final':>7} {'Retention':>10}")
    print("  " + "─" * 54)

    for person in all_people:
        raw   = raw_counts.get(person, 0)
        conv  = conv_counts.get(person, 0)
        final = final_counts.get(person, 0)
        ret   = f"{final / raw * 100:.0f}%" if raw > 0 else "—"
        flag  = (" ✅" if final / max(raw, 1) >= 0.8
                 else (" ⚠️" if final / max(raw, 1) >= 0.5 else " ❌"))
        print(f"  {person:<16} {raw:>5} {conv:>10} {final:>7} {ret:>10}{flag}")

    print("  " + "─" * 54)
    total_raw   = sum(raw_counts.values())
    total_conv  = sum(conv_counts.values())
    total_final = sum(final_counts.values())
    total_ret   = f"{total_final / total_raw * 100:.0f}%" if total_raw > 0 else "—"
    print(f"  {'TOTAL':<16} {total_raw:>5} {total_conv:>10} {total_final:>7} {total_ret:>10}")

    # --- Visualization ---
    fig, axes = plt.subplots(1, 2, figsize=(14, max(5, len(all_people) * 0.45 + 2)))
    fig.suptitle("Dataset Analysis After Preprocessing (Steps 1–4)",
                 fontsize=13, fontweight='bold')

    short = [p[:12] for p in all_people]
    x = range(len(all_people))
    w = 0.28

    # Chart 1: grouped bars — raw / converted / final per person
    axes[0].bar([i - w for i in x], [raw_counts.get(p, 0) for p in all_people],
                width=w, label='Raw', color='#3498db', alpha=0.85)
    axes[0].bar(list(x), [conv_counts.get(p, 0) for p in all_people],
                width=w, label='Converted (blur filtered)', color='#f39c12', alpha=0.85)
    axes[0].bar([i + w for i in x], [final_counts.get(p, 0) for p in all_people],
                width=w, label='Final Face Crops', color='#2ecc71', alpha=0.85)
    axes[0].set_xticks(list(x))
    axes[0].set_xticklabels(short, rotation=45, ha='right', fontsize=8)
    axes[0].set_ylabel("Image Count")
    axes[0].set_title("Images per Person at Each Stage")
    axes[0].legend(fontsize=9)
    axes[0].grid(True, alpha=0.3, axis='y')

    # Chart 2: retention rate (raw → final face crops)
    retention  = [(final_counts.get(p, 0) / max(raw_counts.get(p, 1), 1)) * 100
                  for p in all_people]
    bar_colors = ['#2ecc71' if r >= 80 else ('#f39c12' if r >= 50 else '#e74c3c')
                  for r in retention]
    axes[1].barh(list(x), retention, color=bar_colors, alpha=0.85)
    axes[1].set_yticks(list(x))
    axes[1].set_yticklabels(short, fontsize=8)
    axes[1].axvline(x=80, color='gray', linestyle='--', alpha=0.5, label='80% target')
    axes[1].set_xlabel("Retention Rate (%)")
    axes[1].set_title("Face Crop Retention Rate (Raw → Final)")
    axes[1].set_xlim(0, 115)
    axes[1].legend(fontsize=9)
    axes[1].grid(True, alpha=0.3, axis='x')
    for i, r in enumerate(retention):
        axes[1].text(r + 1, i, f'{r:.0f}%', va='center', fontsize=8)

    plt.tight_layout()
    plt.show()

    # --- Summary ---
    print(f"\n📋 SUMMARY:")
    print(f"  People:              {len(all_people)}")
    print(f"  Raw images:          {total_raw}")
    if total_raw > 0:
        blurry_dropped = total_raw - total_conv
        print(f"  Dropped (blurry):    {blurry_dropped}  ({blurry_dropped / total_raw * 100:.1f}%)")
        print(f"  After conversion:    {total_conv}  ({total_conv / total_raw * 100:.1f}%)")
        print(f"  Final face crops:    {total_final}  ({total_final / total_raw * 100:.1f}% overall retention)")

        overall_ret = total_final / total_raw
        if overall_ret < 0.5:
            print(f"\n  ❌ Low retention (<50%). Check: lighting, face angles, or lower BLUR_THRESHOLD.")
        elif overall_ret < 0.8:
            print(f"\n  ⚠️ Moderate retention. Some images had undetectable faces or were blurry.")
        else:
            print(f"\n  ✅ Good retention rate. Pipeline is working well.")

# Analyze dataset after completing Steps 1–4
analyze_preprocessed_dataset()
# Out:
# 📊 DATASET ANALYSIS AFTER PREPROCESSING
# ============================================================
#
#   Person             Raw  Converted   Final  Retention
#   ──────────────────────────────────────────────────────
#   Dr.Nurul            11          8       8        73% ⚠️
#   benjamin            41         29      13        32% ❌
#   chern_tak           36         25      11        31% ❌
#   chillien            14         10       9        64% ⚠️
#   daniel              84         59      38        45% ❌
#   dylan               40         28      23        57% ⚠️
#   han_soon            11          8       8        73% ⚠️
#   harry               10          7       7        70% ⚠️
#   isaac               10          7       1        10% ❌
#   jing_ang             9          6       6        67% ⚠️
#   jun_wei              9          6       6        67% ⚠️
#   kang_kai            16         11      11        69% ⚠️
#   marion              11          8       8        73% ⚠️
#   qi_xuan             11          8       8        73% ⚠️
#   shuang_quan         75         53      22        29% ❌
#   wee_xuan            16         11      10        62% ⚠️
#   xiang_yue           14         10       8        57% ⚠️
#   xu_sheng            23         16       5        22% ❌
#   yoke_hong           49         34      22        45% ❌
#   yong_kang           13          9      10        77% ⚠️
#   zi_herng            11          8       9        82% ✅
#   ──────────────────────────────────────────────────────
#   TOTAL              514        361     243        47%
# 📋 SUMMARY:
#   People:              21
#   Raw images:          514
#   Dropped (blurry):    153  (29.8%)
#   After conversion:    361  (70.2%)
#   Final face crops:    243  (47.3% overall retention)
#
#   ❌ Low retention (<50%). Check: lighting, face angles, or lower BLUR_THRESHOLD.

# %% [markdown]
# # 📊 Processing Summary & Statistics
#
# View the complete processing statistics:

# %%
def generate_processing_summary():
    """Generate comprehensive processing summary across all pipeline stages."""
    
    print("📊 COMPLETE PROCESSING SUMMARY")
    print("=" * 60)
    
    # count images in a folder
    def count_folder_images(folder_path):
        if not os.path.exists(folder_path):
            return 0, 0  # (people_count, image_count)
        person_dirs = [d for d in os.listdir(folder_path) 
                      if os.path.isdir(os.path.join(folder_path, d))]
        total_files = 0
        for person in person_dirs:
            person_path = os.path.join(folder_path, person)
            files = [f for f in os.listdir(person_path) 
                    if Path(f).suffix.lower() in {'.jpg', '.jpeg', '.png'}]
            total_files += len(files)
        return len(person_dirs), total_files
    
    # Original raw dataset
    raw_people, raw_total = count_folder_images(RAW_FOLDER)
    print(f"\n📷 RAW DATASET:")
    print(f"  • People: {raw_people}")
    print(f"  • Images: {raw_total}")
    if raw_people > 0:
        print(f"  • Avg per person: {raw_total / raw_people:.1f}")
    
    # Processing stages
    stages = [
        ("CONVERTED",       CONVERTED_FOLDER,       None),
        ("PREPROCESSED",    PREPROCESSED_FOLDER,    None),
        ("FACES DETECTED",  FACES_DETECTED_FOLDER,  "detection"),
        ("FINAL PROCESSED", FINAL_PROCESSED_FOLDER, None),
        ("TEST PROCESSED",  TEST_PROCESSED_FOLDER,  "test"),
        ("AUGMENTED",       AUGMENTED_FOLDER,       "augmentation"),
    ]
    
    for stage_name, folder_path, stage_type in stages:
        people_count, file_count = count_folder_images(folder_path)
        
        if os.path.exists(folder_path):
            print(f"\n{stage_name}:")
            print(f"  • People: {people_count}")
            print(f"  • Images: {file_count}")
            
            if stage_type == "augmentation" and raw_total > 0 and file_count > 0:
                multiplication = file_count / raw_total
                print(f"  • Dataset multiplication: {multiplication:.1f}x")
                if people_count > 0:
                    print(f"  • Avg per person: {file_count / people_count:.1f}")
            
            if stage_type == "detection" and raw_total > 0 and file_count > 0:
                print(f"  • Faces per original: {file_count / raw_total:.1f}")
        else:
            print(f"\n❌ {stage_name}: Folder not created yet")
    
    print(f"\n{'=' * 60}")
    print(f"✨ Summary complete!")

generate_processing_summary()
# Out:
# 📊 COMPLETE PROCESSING SUMMARY
# ============================================================
#
# 📷 RAW DATASET:
#   • People: 21
#   • Images: 174
#   • Avg per person: 8.3
#
# CONVERTED:
#   • People: 21
#   • Images: 361
#
# PREPROCESSED:
#   • People: 21
#   • Images: 361
#
# FACES DETECTED:
#   • People: 21
#   • Images: 243
#   • Faces per original: 1.4
#
# FINAL PROCESSED:
#   • People: 21
#   • Images: 243
#
# TEST PROCESSED:
#   • People: 21
#   • Images: 102
#
# AUGMENTED:
#   • People: 21
#   • Images: 0
#
# ============================================================
# ✨ Summary complete!
